# %%
import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /content/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /content/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /content/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /content/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /content/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /content/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /content/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /content/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /content/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
from nltk.corpus import wordnet
wordnet.synsets('car')

# car.n.01
# car -> 単語名
# n   -> 属性（名詞、動詞、、、）
# 01  -> index
# Out:
# [Synset('car.n.01'),
#  Synset('car.n.02'),
#  Synset('car.n.03'),
#  Synset('car.n.04'),
#  Synset('cable_car.n.01')]

# %%
wordnet.synsets('日本')
# Out:
# []

# %%
wordnet.synsets('Japanese')
# Out:
# [Synset('japanese.n.01'), Synset('japanese.n.02'), Synset('japanese.a.01')]

# %%
# group の定義を確認
car = wordnet.synset('car.n.01')
car.definition()
# Out:
# 'a motor vehicle with four wheels; usually propelled by an internal combustion engine'

# %%
car = wordnet.synset('car.n.02')
car.definition()
# Out:
# 'a wheeled vehicle adapted to the rails of railroad'

# %%
# group の中身を確認
car.lemma_names()
# Out:
# ['car', 'railcar', 'railway_car', 'railroad_car']

# %%
# 単語ネットワークの確認
car.hypernym_paths()[0]
# 抽象的な表現から具体的な表現に変わっていく
# Out:
# [Synset('entity.n.01'),
#  Synset('physical_entity.n.01'),
#  Synset('object.n.01'),
#  Synset('whole.n.02'),
#  Synset('artifact.n.01'),
#  Synset('instrumentality.n.03'),
#  Synset('container.n.01'),
#  Synset('wheeled_vehicle.n.01'),
#  Synset('car.n.02')]

# %%
# wordnetによる意味の類似度
car = wordnet.synset('car.n.01')
novel = wordnet.synset('novel.n.01')
dog = wordnet.synset('dog.n.01')
motorcycle = wordnet.synset('motorcycle.n.01')

car.path_similarity(novel)
# Out:
# 0.05555555555555555

# %%
car.path_similarity(dog)
# Out:
# 0.07692307692307693

# %%
car.path_similarity(motorcycle)
# Out:
# 0.3333333333333333

# %% [markdown]
# # WordNet Interface

# %% [markdown]
# http://www.nltk.org/howto/wordnet.html
#
# WordNet is just another NLTK corpus reader.

# %%
from nltk.corpus import wordnet

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# synset()
# this function has an optional pos argument which lets you constrain the parts of speech of the word

# %% [markdown]
# ## Words

# %%
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
wn.synsets('dog', pos=wn.VERB)
# Out:
# [Synset('chase.v.01')]

# %% [markdown]
# The other parts of speech are NOUN, ADJ and ADV.
# A synset is identified with a 3-part name of the form:
# word.pos.nn:

# %%
wn.synset('dog.n.01')
# Out:
# Synset('dog.n.01')

# %%
print(wn.synset('dog.n.01').definition())
# Out:
# a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds

# %%
len(wn.synset('dog.n.01').examples())
# Out:
# 1

# %%
print(wn.synset('dog.n.01').examples()[0])
# Out:
# the dog barked all night

# %%
# group の中身をみる
wn.synset('dog.n.01').lemmas()
# Out:
# [Lemma('dog.n.01.dog'),
#  Lemma('dog.n.01.domestic_dog'),
#  Lemma('dog.n.01.Canis_familiaris')]

# %%
[str(lemma.name()) for lemma in wn.synset('dog.n.01').lemmas()]
# Out:
# ['dog', 'domestic_dog', 'Canis_familiaris']

# %%
wn.lemma('dog.n.01.dog').synset()
# Out:
# Synset('dog.n.01')

# %% [markdown]
# The WordNet corpus reader gives access to the Open Multilingual WordNet,
# using ISO-639 language codes.

# %%
sorted(wn.langs())
# Out:
# ['als',
#  'arb',
#  'bul',
#  'cat',
#  'cmn',
#  'dan',
#  'ell',
#  'eng',
#  'eus',
#  'fas',
#  'fin',
#  'fra',
#  'glg',
#  'heb',
#  'hrv',
#  'ind',
#  'ita',
#  'jpn',
#  'nld',
#  'nno',
#  'nob',
#  'pol',
#  'por',
#  'qcn',
#  'slv',
#  'spa',
#  'swe',
#  'tha',
#  'zsm']

# %%
wn.synsets(b'\xe7\x8a\xac'.decode('utf-8'), lang='jpn')
# Out:
# [Synset('dog.n.01'), Synset('spy.n.01')]

# %%
wn.synset('spy.n.01').lemma_names('jpn')
# Out:
# ['いぬ',
#  'スパイ',
#  '回者',
#  '回し者',
#  '密偵',
#  '工作員',
#  '廻者',
#  '廻し者',
#  '探',
#  '探り',
#  '犬',
#  '秘密捜査員',
#  'まわし者',
#  '諜報員',
#  '諜者',
#  '間者',
#  '間諜',
#  '隠密']

# %%
wn.synset('dog.n.01').lemma_names('ita')
# Out:
# ['cane', 'Canis_familiaris']

# %%
wn.lemmas('cane', lang='ita')
# Out:
# [Lemma('dog.n.01.cane'),
#  Lemma('cramp.n.02.cane'),
#  Lemma('hammer.n.01.cane'),
#  Lemma('bad_person.n.01.cane'),
#  Lemma('incompetent.n.01.cane')]

# %%
sorted(wn.synset('dog.n.01').lemmas('dan'))
# Out:
# [Lemma('dog.n.01.hund'),
#  Lemma('dog.n.01.køter'),
#  Lemma('dog.n.01.vovhund'),
#  Lemma('dog.n.01.vovse')]

# %%
sorted(wn.synset('dog.n.01').lemmas('por'))
# Out:
# [Lemma('dog.n.01.cachorra'),
#  Lemma('dog.n.01.cachorro'),
#  Lemma('dog.n.01.cadela'),
#  Lemma('dog.n.01.cão')]

# %%
dog_lemma = wn.lemma(b'dog.n.01.c\xc3\xa3o'.decode('utf-8'), lang='por')
dog_lemma
# Out:
# Lemma('dog.n.01.cão')

# %%
dog_lemma.lang()
# Out:
# 'por'

# %%
len(wordnet.all_lemma_names(pos='n', lang='jpn'))
# Out:
# 64797

# %% [markdown]
# ## Synsets
# synset: a set of synonyms that share a common meaning.

# %%
dog = wn.synset('dog.n.01')

# %%
dog.hypernyms()
# Out:
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]

# %%
dog.hyponyms()
# Out:
# [Synset('basenji.n.01'),
#  Synset('corgi.n.01'),
#  Synset('cur.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('griffon.n.02'),
#  Synset('hunting_dog.n.01'),
#  Synset('lapdog.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('newfoundland.n.01'),
#  Synset('pooch.n.01'),
#  Synset('poodle.n.01'),
#  Synset('pug.n.01'),
#  Synset('puppy.n.01'),
#  Synset('spitz.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('working_dog.n.01')]

# %%
dog.member_holonyms()
# Out:
# [Synset('canis.n.01'), Synset('pack.n.06')]

# %%
dog.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %%
wn.synset('dog.n.01').lowest_common_hypernyms(wn.synset('cat.n.01'))
# Out:
# [Synset('carnivore.n.01')]

# %% [markdown]
# Note that some relations are defined by WordNet only over Lemmas.

# %%
good = wn.synset('good.a.01')

# %%
good.antonyms()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-18d98d9a44ce> in <module>()
# ----> 1 good.antonyms()
#
# AttributeError: 'Synset' object has no attribute 'antonyms'

# %%
good.lemmas()[0].antonyms()
# Out:
# [Lemma('bad.a.01.bad')]

# %% [markdown]
# The relations that are currently defined in this way are antonyms,
# derivationally_related_forms and pertainyms.

# %% [markdown]
# ## Lemmas

# %%
eat = wn.lemma('eat.v.03.eat')
eat
# Out:
# Lemma('feed.v.06.eat')

# %%
print(eat.key())
# Out:
# eat%2:34:02::

# %%
eat.count()
# Out:
# 4

# %%
wn.lemma_from_key(eat.key())
# Out:
# Lemma('feed.v.06.eat')

# %%
wn.lemma_from_key(eat.key()).synset()
# Out:
# Synset('feed.v.06')

# %%
wn.lemma_from_key('feebleminded%5:00:00:retarded:00')
# Out:
# Lemma('backward.s.03.feebleminded')

# %%
for lemma in wn.synset('eat.v.03').lemmas():
  print(lemma, lemma.count())
# Out:
# Lemma('feed.v.06.feed') 3
# Lemma('feed.v.06.eat') 4

# %%
for lemma in wn.lemmas('eat', 'v'):
  print(lemma, lemma.count)
# Out:
# Lemma('eat.v.01.eat') <bound method Lemma.count of Lemma('eat.v.01.eat')>
# Lemma('eat.v.02.eat') <bound method Lemma.count of Lemma('eat.v.02.eat')>
# Lemma('feed.v.06.eat') <bound method Lemma.count of Lemma('feed.v.06.eat')>
# Lemma('eat.v.04.eat') <bound method Lemma.count of Lemma('eat.v.04.eat')>
# Lemma('consume.v.05.eat') <bound method Lemma.count of Lemma('consume.v.05.eat')>
# Lemma('corrode.v.01.eat') <bound method Lemma.count of Lemma('corrode.v.01.eat')>

# %% [markdown]
# Lemmas can also habe relations between them:

# %%
vocal = wn.lemma('vocal.a.01.vocal')
vocal.derivationally_related_forms()
# Out:
# [Lemma('vocalize.v.02.vocalize')]

# %%
vocal.pertainyms()
# Out:
# [Lemma('voice.n.02.voice')]

# %%
vocal.antonyms()
# Out:
# [Lemma('instrumental.a.01.instrumental')]

# %% [markdown]
# The three relations above exist only on lemmas, not on synsets.

# %% [markdown]
# ## Verb Frames

# %%
wn.synset('think.v.01').frame_ids()
# Out:
# [5, 9]

# %%
for lemma in wn.synset('think.v.01').lemmas():
  print(lemma, lemma.frame_ids())
  print(" | ".join(lemma.frame_strings()))
# Out:
# Lemma('think.v.01.think') [5, 9]
# Something think something Adjective/Noun | Somebody think somebody
# Lemma('think.v.01.believe') [5, 9]
# Something believe something Adjective/Noun | Somebody believe somebody
# Lemma('think.v.01.consider') [5, 9]
# Something consider something Adjective/Noun | Somebody consider somebody
# Lemma('think.v.01.conceive') [5, 9]
# Something conceive something Adjective/Noun | Somebody conceive somebody

# %%
wn.synset('stretch.v.02').frame_ids()
# Out:
# [8]

# %%
wn.synset('stretch.v.02').definition()
# Out:
# "extend one's limbs or muscles, or the entire body"

# %%
for lemma in wn.synset('stretch.v.02').lemmas():
  print(lemma, lemma.frame_ids())
  print(" | ".join(lemma.frame_strings()))
# Out:
# Lemma('stretch.v.02.stretch') [8, 2]
# Somebody stretch something | Somebody stretch
# Lemma('stretch.v.02.extend') [8]
# Somebody extend something

# %% [markdown]
# ## Similarity

# %%
dog = wn.synset('dog.n.01')
cat = wn.synset('cat.n.01')

hit = wn.synset('hit.v.01')
slap = wn.synset('slap.v.01')

# %%
dog.path_similarity(cat)
# Out:
# 0.2

# %%
hit.path_similarity(slap)
# Out:
# 0.14285714285714285

# %%
wn.path_similarity(hit, slap)
# Out:
# 0.14285714285714285

# %%
print(hit.path_similarity(slap, simulate_root=False))
# Out:
# None

# %%
print(wn.path_similarity(hit, slap, simulate_root=False))
# Out:
# None

# %%
from nltk.corpus import wordnet_ic
brown_ic = wordnet_ic.ic('ic-brown.dat')
se,cor_ic = wordnet_ic.ic('ic-semcor.dat')

# %%
from nltk.corpus import wordnet_ic
brown_ic = wordnet_ic.ic('ic-brown.dat')
semcor_ic = wordnet_ic.ic('ic-semcor.dat')

# %%
from nltk.corpus import genesis
genesis_ic = wn.ic(genesis, False, 0.0)

# %% [markdown]
# The relationship is given by the equation
#
# 1 / (IC(s1) + IC(s2) * IC(lcs)).

# %%
dog.res_similarity(cat, brown_ic)
# Out:
# 7.911666509036577

# %%
dog.res_similarity(cat, genesis_ic)
# Out:
# 7.204023991374837

# %% [markdown]
# The relationship is given by the equation
#
# 2 * IC(lcs) / (IC(s1) + IC(s2))

# %%
dog.jcn_similarity(cat, brown_ic)
# Out:
# 0.4497755285516739

# %%
dog.jcn_similarity(cat, genesis_ic)
# Out:
# 0.28539390848096946

# %%
dog.lin_similarity(cat, semcor_ic)
# Out:
# 0.8863288628086228

# %% [markdown]
# ## Access to all Synsets

# %% [markdown]
# Iterate over all the noun synsets:

# %%
for synset in list(wn.all_synsets('n'))[:10]:
  print(synset)
# Out:
# Synset('entity.n.01')
# Synset('physical_entity.n.01')
# Synset('abstraction.n.06')
# Synset('thing.n.12')
# Synset('object.n.01')
# Synset('whole.n.02')
# Synset('congener.n.03')
# Synset('living_thing.n.01')
# Synset('organism.n.01')
# Synset('benthos.n.02')

# %% [markdown]
# Get all synsets for this word, possibly restricted by POS:

# %%
wn.synsets('dog')
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
wn.synsets('dog', pos='v')
# Out:
# [Synset('chase.v.01')]

# %% [markdown]
# Walk through the noun synsets looking at their hypernyms:

# %%
from itertools import islice
for synset in islice(wn.all_synsets('n'), 5):
  print(synset, synset.hypernyms())
# Out:
# Synset('entity.n.01') []
# Synset('physical_entity.n.01') [Synset('entity.n.01')]
# Synset('abstraction.n.06') [Synset('entity.n.01')]
# Synset('thing.n.12') [Synset('physical_entity.n.01')]
# Synset('object.n.01') [Synset('physical_entity.n.01')]

# %% [markdown]
# ## Morphy

# %% [markdown]
# Look up forms not in WordNet, with the help of Morphy

# %%
wn.morphy('denied', wn.NOUN)

# %%
print(wn.morphy('denied', wn.VERB))
# Out:
# deny

# %%
wn.synsets('denied', wn.NOUN)
# Out:
# []

# %%
wn.synsets('denied', wn.VERB)
# Out:
# [Synset('deny.v.01'),
#  Synset('deny.v.02'),
#  Synset('deny.v.03'),
#  Synset('deny.v.04'),
#  Synset('deny.v.05'),
#  Synset('traverse.v.03'),
#  Synset('deny.v.07')]

# %% [markdown]
# Morphy uses a combination of inflectional ending rules and exception lists to handle a variety of different possibilities:

# %%
print(wn.morphy('dogs'))
# Out:
# dog

# %%
print(wn.morphy('aardwolves'))
# Out:
# aardwolf

# %%
print(wn.morphy('book', wn.NOUN))
# Out:
# book

# %%
wn.morphy('hardrock', wn.ADV)

# %%
wn.morphy('book', wn.ADJ)

# %%
wn.morphy('his', wn.NOUN)

# %% [markdown]
# ## Synset Closures

# %% [markdown]
# Compute transitsive closures of synsets

# %%
dog = wn.synset('dog.n.01')
hypo = lambda s: s.hyponyms()
hyper = lambda s: s.hypernyms()
list(dog.closure(hypo, depth=1)) == dog.hyponyms()
# Out:
# True

# %%
list(dog.closure(hyper, depth=1)) == dog.hypernyms()
# Out:
# True

# %%
list(dog.closure(hypo))
# Out:
# [Synset('basenji.n.01'),
#  Synset('corgi.n.01'),
#  Synset('cur.n.01'),
#  Synset('dalmatian.n.02'),
#  Synset('great_pyrenees.n.01'),
#  Synset('griffon.n.02'),
#  Synset('hunting_dog.n.01'),
#  Synset('lapdog.n.01'),
#  Synset('leonberg.n.01'),
#  Synset('mexican_hairless.n.01'),
#  Synset('newfoundland.n.01'),
#  Synset('pooch.n.01'),
#  Synset('poodle.n.01'),
#  Synset('pug.n.01'),
#  Synset('puppy.n.01'),
#  Synset('spitz.n.01'),
#  Synset('toy_dog.n.01'),
#  Synset('working_dog.n.01'),
#  Synset('cardigan.n.02'),
#  Synset('pembroke.n.01'),
#  Synset('feist.n.01'),
#  Synset('pariah_dog.n.01'),
#  Synset('liver-spotted_dalmatian.n.01'),
#  Synset('brabancon_griffon.n.01'),
#  Synset('courser.n.03'),
#  Synset('dachshund.n.01'),
#  Synset('hound.n.01'),
#  Synset('rhodesian_ridgeback.n.01'),
#  Synset('sporting_dog.n.01'),
#  Synset('terrier.n.01'),
#  Synset('large_poodle.n.01'),
#  Synset('miniature_poodle.n.01'),
#  Synset('standard_poodle.n.01'),
#  Synset('toy_poodle.n.01'),
#  Synset('chow.n.03'),
#  Synset('keeshond.n.01'),
#  Synset('pomeranian.n.01'),
#  Synset('samoyed.n.03'),
#  Synset('chihuahua.n.03'),
#  Synset('japanese_spaniel.n.01'),
#  Synset('maltese_dog.n.01'),
#  Synset('pekinese.n.01'),
#  Synset('shih-tzu.n.01'),
#  Synset('toy_spaniel.n.01'),
#  Synset('toy_terrier.n.01'),
#  Synset('boxer.n.04'),
#  Synset('bull_mastiff.n.01'),
#  Synset('bulldog.n.01'),
#  Synset('eskimo_dog.n.01'),
#  Synset('great_dane.n.01'),
#  Synset('guide_dog.n.01'),
#  Synset('hearing_dog.n.01'),
#  Synset('mastiff.n.01'),
#  Synset('police_dog.n.01'),
#  Synset('saint_bernard.n.01'),
#  Synset('seizure-alert_dog.n.01'),
#  Synset('sennenhunde.n.01'),
#  Synset('shepherd_dog.n.01'),
#  Synset('sled_dog.n.01'),
#  Synset('watchdog.n.02'),
#  Synset('sausage_dog.n.01'),
#  Synset('afghan_hound.n.01'),
#  Synset('basset.n.01'),
#  Synset('beagle.n.01'),
#  Synset('bloodhound.n.01'),
#  Synset('bluetick.n.01'),
#  Synset('boarhound.n.01'),
#  Synset('coonhound.n.01'),
#  Synset('foxhound.n.01'),
#  Synset('greyhound.n.01'),
#  Synset('harrier.n.02'),
#  Synset('ibizan_hound.n.01'),
#  Synset('norwegian_elkhound.n.01'),
#  Synset('otterhound.n.01'),
#  Synset('plott_hound.n.01'),
#  Synset('redbone.n.01'),
#  Synset('saluki.n.01'),
#  Synset('scottish_deerhound.n.01'),
#  Synset('staghound.n.01'),
#  Synset('weimaraner.n.01'),
#  Synset('wolfhound.n.01'),
#  Synset('bird_dog.n.01'),
#  Synset('griffon.n.03'),
#  Synset('pointer.n.04'),
#  Synset('retriever.n.01'),
#  Synset('setter.n.02'),
#  Synset('spaniel.n.01'),
#  Synset('water_dog.n.02'),
#  Synset('airedale.n.01'),
#  Synset('australian_terrier.n.01'),
#  Synset('bedlington_terrier.n.01'),
#  Synset('border_terrier.n.01'),
#  Synset('boston_bull.n.01'),
#  Synset('bullterrier.n.01'),
#  Synset('cairn.n.02'),
#  Synset('dandie_dinmont.n.01'),
#  Synset('fox_terrier.n.01'),
#  Synset('irish_terrier.n.01'),
#  Synset('kerry_blue_terrier.n.01'),
#  Synset('lhasa.n.02'),
#  Synset('norfolk_terrier.n.01'),
#  Synset('norwich_terrier.n.01'),
#  Synset('rat_terrier.n.01'),
#  Synset('schnauzer.n.01'),
#  Synset('scotch_terrier.n.01'),
#  Synset('silky_terrier.n.01'),
#  Synset('skye_terrier.n.01'),
#  Synset('soft-coated_wheaten_terrier.n.01'),
#  Synset('tibetan_terrier.n.01'),
#  Synset('west_highland_white_terrier.n.01'),
#  Synset('wirehair.n.01'),
#  Synset('yorkshire_terrier.n.01'),
#  Synset('english_toy_spaniel.n.01'),
#  Synset('king_charles_spaniel.n.01'),
#  Synset('papillon.n.01'),
#  Synset('french_bulldog.n.01'),
#  Synset('seeing_eye_dog.n.01'),
#  Synset('tibetan_mastiff.n.01'),
#  Synset('appenzeller.n.01'),
#  Synset('bernese_mountain_dog.n.01'),
#  Synset('entlebucher.n.01'),
#  Synset('greater_swiss_mountain_dog.n.01'),
#  Synset('belgian_sheepdog.n.01'),
#  Synset('border_collie.n.01'),
#  Synset('bouvier_des_flandres.n.01'),
#  Synset('briard.n.01'),
#  Synset('collie.n.01'),
#  Synset('german_shepherd.n.01'),
#  Synset('kelpie.n.02'),
#  Synset('komondor.n.01'),
#  Synset('old_english_sheepdog.n.01'),
#  Synset('rottweiler.n.01'),
#  Synset('shetland_sheepdog.n.01'),
#  Synset('malamute.n.01'),
#  Synset('siberian_husky.n.01'),
#  Synset('attack_dog.n.01'),
#  Synset('housedog.n.01'),
#  Synset('kuvasz.n.01'),
#  Synset('pinscher.n.01'),
#  Synset('schipperke.n.01'),
#  Synset('black-and-tan_coonhound.n.01'),
#  Synset('coondog.n.01'),
#  Synset('american_foxhound.n.01'),
#  Synset('english_foxhound.n.01'),
#  Synset('walker_hound.n.01'),
#  Synset('italian_greyhound.n.01'),
#  Synset('whippet.n.01'),
#  Synset('borzoi.n.01'),
#  Synset('irish_wolfhound.n.01'),
#  Synset('german_short-haired_pointer.n.01'),
#  Synset('vizsla.n.01'),
#  Synset('chesapeake_bay_retriever.n.01'),
#  Synset('curly-coated_retriever.n.01'),
#  Synset('flat-coated_retriever.n.01'),
#  Synset('golden_retriever.n.01'),
#  Synset('labrador_retriever.n.01'),
#  Synset('english_setter.n.01'),
#  Synset('gordon_setter.n.01'),
#  Synset('irish_setter.n.01'),
#  Synset('brittany_spaniel.n.01'),
#  Synset('clumber.n.01'),
#  Synset('cocker_spaniel.n.01'),
#  Synset('field_spaniel.n.01'),
#  Synset('springer_spaniel.n.01'),
#  Synset('sussex_spaniel.n.01'),
#  Synset('water_spaniel.n.01'),
#  Synset('american_staffordshire_terrier.n.01'),
#  Synset('staffordshire_bullterrier.n.01'),
#  Synset('smooth-haired_fox_terrier.n.01'),
#  Synset('wire-haired_fox_terrier.n.01'),
#  Synset('manchester_terrier.n.01'),
#  Synset('giant_schnauzer.n.01'),
#  Synset('miniature_schnauzer.n.01'),
#  Synset('standard_schnauzer.n.01'),
#  Synset('clydesdale_terrier.n.01'),
#  Synset('lakeland_terrier.n.01'),
#  Synset('welsh_terrier.n.01'),
#  Synset('blenheim_spaniel.n.01'),
#  Synset('groenendael.n.01'),
#  Synset('malinois.n.01'),
#  Synset('affenpinscher.n.01'),
#  Synset('doberman.n.01'),
#  Synset('miniature_pinscher.n.01'),
#  Synset('english_springer.n.01'),
#  Synset('welsh_springer_spaniel.n.01'),
#  Synset('american_water_spaniel.n.01'),
#  Synset('irish_water_spaniel.n.01'),
#  Synset('toy_manchester.n.01'),
#  Synset('sealyham_terrier.n.01')]

# %% [markdown]
# ## Regression Tests

# %%
wn.synsets('book', wn.NOUN)
# Out:
# [Synset('book.n.01'),
#  Synset('book.n.02'),
#  Synset('record.n.05'),
#  Synset('script.n.01'),
#  Synset('ledger.n.01'),
#  Synset('book.n.06'),
#  Synset('book.n.07'),
#  Synset('koran.n.01'),
#  Synset('bible.n.01'),
#  Synset('book.n.10'),
#  Synset('book.n.11')]

# %%
wn.synsets('book', wn.ADJ)
# Out:
# []

# %%
wn.morphy('book', wn.NOUN)
# Out:
# 'book'

# %%
wn.morphy('book', wn.ADJ)

# %%
t = wn.synsets('picasso')[0]

# %%
m = wn.synsets('male')[1]

# %%
t.wup_similarity(m)
# Out:
# 0.631578947368421

# %%
t = wn.synsets('titan')[1]

# %%
s = wn.synsets('say', wn.VERB)[0]

# %%
print(t.wup_similarity(s))
# Out:
# None

# %%
a = wn.synsets("writings")[0]
b = wn.synsets("scripture")[0]
brown_ic = wordnet_ic.ic('ic-brown.dat')
a.jcn_similarity(b, brown_ic)
# Out:
# 0.17546021191621833

# %%
from nltk.corpus.reader.wordnet import information_content
s = wn.synsets('say', wn.VERB)[0]
information_content(s, brown_ic)
# Out:
# 4.623712110017779

# %%
k = wn.synsets("jefferson")[0].lemmas()[0].key()
wn.lemma_from_key(k)
# Out:
# Lemma('jefferson.n.01.Jefferson')

# %%
wn.lemma_from_key(k.upper())
# Out:
# Lemma('jefferson.n.01.Jefferson')

# %%
from nltk.corpus import wordnet as wn
for s in wn.all_synsets(wn.NOUN):
  if s in wn.all_synsets(wn.NOUN):
    print(s, s.root_hypernyms())
# Out:
# Synset('entity.n.01') [Synset('entity.n.01')]
# Synset('physical_entity.n.01') [Synset('entity.n.01')]
# Synset('abstraction.n.06') [Synset('entity.n.01')]
# Synset('thing.n.12') [Synset('entity.n.01')]
# Synset('object.n.01') [Synset('entity.n.01')]
# Synset('whole.n.02') [Synset('entity.n.01')]
# Synset('congener.n.03') [Synset('entity.n.01')]
# Synset('living_thing.n.01') [Synset('entity.n.01')]
# Synset('organism.n.01') [Synset('entity.n.01')]
# Synset('benthos.n.02') [Synset('entity.n.01')]
# Synset('dwarf.n.03') [Synset('entity.n.01')]
# Synset('heterotroph.n.01') [Synset('entity.n.01')]
# Synset('parent.n.02') [Synset('entity.n.01')]
# Synset('life.n.10') [Synset('entity.n.01')]
# Synset('biont.n.01') [Synset('entity.n.01')]
# Synset('cell.n.02') [Synset('entity.n.01')]
# Synset('causal_agent.n.01') [Synset('entity.n.01')]
# Synset('person.n.01') [Synset('entity.n.01')]
# Synset('animal.n.01') [Synset('entity.n.01')]
# Synset('plant.n.02') [Synset('entity.n.01')]
# Synset('native.n.03') [Synset('entity.n.01')]
# Synset('natural_object.n.01') [Synset('entity.n.01')]
# Synset('substance.n.01') [Synset('entity.n.01')]
# Synset('substance.n.07') [Synset('entity.n.01')]
# Synset('matter.n.03') [Synset('entity.n.01')]
# Synset('food.n.01') [Synset('entity.n.01')]
# Synset('nutrient.n.02') [Synset('entity.n.01')]
# Synset('artifact.n.01') [Synset('entity.n.01')]
# Synset('article.n.02') [Synset('entity.n.01')]
# Synset('psychological_feature.n.01') [Synset('entity.n.01')]
# Synset('cognition.n.01') [Synset('entity.n.01')]
# Synset('motivation.n.01') [Synset('entity.n.01')]
# Synset('attribute.n.02') [Synset('entity.n.01')]
# Synset('state.n.02') [Synset('entity.n.01')]
# Synset('feeling.n.01') [Synset('entity.n.01')]
# Synset('location.n.01') [Synset('entity.n.01')]
# Synset('shape.n.02') [Synset('entity.n.01')]
# Synset('time.n.05') [Synset('entity.n.01')]
# Synset('space.n.01') [Synset('entity.n.01')]
# Synset('absolute_space.n.01') [Synset('entity.n.01')]
# Synset('phase_space.n.01') [Synset('entity.n.01')]
# Synset('event.n.01') [Synset('entity.n.01')]
# Synset('process.n.06') [Synset('entity.n.01')]
# Synset('act.n.02') [Synset('entity.n.01')]
# Synset('group.n.01') [Synset('entity.n.01')]
# Synset('relation.n.01') [Synset('entity.n.01')]
# Synset('possession.n.02') [Synset('entity.n.01')]
# Synset('social_relation.n.01') [Synset('entity.n.01')]
# Synset('communication.n.02') [Synset('entity.n.01')]
# Synset('measure.n.02') [Synset('entity.n.01')]
# Synset('phenomenon.n.01') [Synset('entity.n.01')]
# Synset('thing.n.02') [Synset('entity.n.01')]
# Synset('kindness.n.03') [Synset('entity.n.01')]
# Synset('abdominoplasty.n.01') [Synset('entity.n.01')]
# Synset('abort.n.01') [Synset('entity.n.01')]
# Synset('accomplishment.n.01') [Synset('entity.n.01')]
# Synset('agon.n.01') [Synset('entity.n.01')]
# Synset('alienation.n.04') [Synset('entity.n.01')]
# Synset('application.n.07') [Synset('entity.n.01')]
# Synset('beachhead.n.02') [Synset('entity.n.01')]
# Synset('cakewalk.n.02') [Synset('entity.n.01')]
# Synset('feat.n.01') [Synset('entity.n.01')]
# Synset('masterpiece.n.02') [Synset('entity.n.01')]
# Synset('masterstroke.n.01') [Synset('entity.n.01')]
# Synset('credit.n.04') [Synset('entity.n.01')]
# Synset('action.n.01') [Synset('entity.n.01')]
# Synset('res_gestae.n.02') [Synset('entity.n.01')]
# Synset('course.n.04') [Synset('entity.n.01')]
# Synset('blind_alley.n.02') [Synset('entity.n.01')]
# Synset('collision_course.n.02') [Synset('entity.n.01')]
# Synset('interaction.n.01') [Synset('entity.n.01')]
# Synset('interplay.n.01') [Synset('entity.n.01')]
# Synset('contact.n.01') [Synset('entity.n.01')]
# Synset('brush.n.09') [Synset('entity.n.01')]
# Synset('eye_contact.n.02') [Synset('entity.n.01')]
# Synset('fetch.n.01') [Synset('entity.n.01')]
# Synset('placement.n.02') [Synset('entity.n.01')]
# Synset('interchange.n.02') [Synset('entity.n.01')]
# Synset('reciprocity.n.02') [Synset('entity.n.01')]
# Synset('cross-fertilization.n.02') [Synset('entity.n.01')]
# Synset('dealings.n.01') [Synset('entity.n.01')]
# Synset('relation.n.06') [Synset('entity.n.01')]
# Synset('playing.n.02') [Synset('entity.n.01')]
# Synset('play.n.17') [Synset('entity.n.01')]
# Synset('boondoggle.n.01') [Synset('entity.n.01')]
# Synset('bowling.n.03') [Synset('entity.n.01')]
# Synset('acquiring.n.01') [Synset('entity.n.01')]
# Synset('causing.n.01') [Synset('entity.n.01')]
# Synset('delivery.n.07') [Synset('entity.n.01')]
# Synset('departure.n.01') [Synset('entity.n.01')]
# Synset('derring-do.n.01') [Synset('entity.n.01')]
# Synset('discovery.n.01') [Synset('entity.n.01')]
# Synset('disposal.n.03') [Synset('entity.n.01')]
# Synset('hit.n.01') [Synset('entity.n.01')]
# Synset('implementation.n.02') [Synset('entity.n.01')]
# Synset('egress.n.03') [Synset('entity.n.01')]
# Synset('equalization.n.01') [Synset('entity.n.01')]
# Synset('exhumation.n.01') [Synset('entity.n.01')]
# Synset('mitzvah.n.02') [Synset('entity.n.01')]
# Synset('propulsion.n.02') [Synset('entity.n.01')]
# Synset('rally.n.02') [Synset('entity.n.01')]
# Synset('recovery.n.03') [Synset('entity.n.01')]
# Synset('running_away.n.01') [Synset('entity.n.01')]
# Synset('stunt.n.01') [Synset('entity.n.01')]
# Synset('touch.n.05') [Synset('entity.n.01')]
# Synset('tour_de_force.n.01') [Synset('entity.n.01')]
# Synset('performance.n.04') [Synset('entity.n.01')]
# Synset('overachievement.n.01') [Synset('entity.n.01')]
# Synset('underachievement.n.01') [Synset('entity.n.01')]
# Synset('record.n.04') [Synset('entity.n.01')]
# Synset('fait_accompli.n.01') [Synset('entity.n.01')]
# Synset('going.n.03') [Synset('entity.n.01')]
# Synset('arrival.n.01') [Synset('entity.n.01')]
# Synset('arrival.n.02') [Synset('entity.n.01')]
# Synset('attainment.n.02') [Synset('entity.n.01')]
# Synset('advent.n.01') [Synset('entity.n.01')]
# Synset('entrance.n.03') [Synset('entity.n.01')]
# Synset('incursion.n.01') [Synset('entity.n.01')]
# Synset('intrusion.n.02') [Synset('entity.n.01')]
# Synset('irruption.n.01') [Synset('entity.n.01')]
# Synset('entree.n.04') [Synset('entity.n.01')]
# Synset('entail.n.02') [Synset('entity.n.01')]
# Synset('registration.n.01') [Synset('entity.n.01')]
# Synset('appearance.n.05') [Synset('entity.n.01')]
# Synset('apparition.n.04') [Synset('entity.n.01')]
# Synset('emergence.n.03') [Synset('entity.n.01')]
# Synset('reappearance.n.02') [Synset('entity.n.01')]
# Synset('comeback.n.02') [Synset('entity.n.01')]
# Synset('return.n.02') [Synset('entity.n.01')]
# Synset('repatriation.n.01') [Synset('entity.n.01')]
# Synset('penetration.n.03') [Synset('entity.n.01')]
# Synset('interpenetration.n.02') [Synset('entity.n.01')]
# Synset('market_penetration.n.01') [Synset('entity.n.01')]
# Synset('anchorage.n.05') [Synset('entity.n.01')]
# Synset('docking.n.01') [Synset('entity.n.01')]
# Synset('landing.n.04') [Synset('entity.n.01')]
# Synset('landing.n.03') [Synset('entity.n.01')]
# Synset('forced_landing.n.01') [Synset('entity.n.01')]
# Synset('breaking_away.n.02') [Synset('entity.n.01')]
# Synset('farewell.n.02') [Synset('entity.n.01')]
# Synset('french_leave.n.01') [Synset('entity.n.01')]
# Synset('valediction.n.02') [Synset('entity.n.01')]
# Synset('disappearance.n.01') [Synset('entity.n.01')]
# Synset('vanishing.n.02') [Synset('entity.n.01')]
# Synset('withdrawal.n.03') [Synset('entity.n.01')]
# Synset('effacement.n.02') [Synset('entity.n.01')]
# Synset('retreat.n.07') [Synset('entity.n.01')]
# Synset('retirement.n.03') [Synset('entity.n.01')]
# Synset('evacuation.n.02') [Synset('entity.n.01')]
# Synset('medical_evacuation.n.01') [Synset('entity.n.01')]
# Synset('decampment.n.02') [Synset('entity.n.01')]
# Synset('desertion.n.01') [Synset('entity.n.01')]
# Synset('abscondment.n.01') [Synset('entity.n.01')]
# Synset('absence_without_leave.n.01') [Synset('entity.n.01')]
# Synset('deviationism.n.01') [Synset('entity.n.01')]
# Synset('emigration.n.01') [Synset('entity.n.01')]
# Synset('immigration.n.01') [Synset('entity.n.01')]
# Synset('aliyah.n.02') [Synset('entity.n.01')]
# Synset('pullback.n.02') [Synset('entity.n.01')]
# Synset('retreat.n.01') [Synset('entity.n.01')]
# Synset('standdown.n.02') [Synset('entity.n.01')]
# Synset('disengagement.n.02') [Synset('entity.n.01')]
# Synset('receding.n.02') [Synset('entity.n.01')]
# Synset('sailing.n.03') [Synset('entity.n.01')]
# Synset('amphibious_landing.n.01') [Synset('entity.n.01')]
# Synset('debarkation.n.01') [Synset('entity.n.01')]
# Synset('going_ashore.n.01') [Synset('entity.n.01')]
# Synset('boarding.n.01') [Synset('entity.n.01')]
# Synset('exit.n.03') [Synset('entity.n.01')]
# Synset('elopement.n.01') [Synset('entity.n.01')]
# Synset('escape.n.01') [Synset('entity.n.01')]
# Synset('evasion.n.04') [Synset('entity.n.01')]
# Synset('slip.n.15') [Synset('entity.n.01')]
# Synset('maneuver.n.05') [Synset('entity.n.01')]
# Synset('clinch.n.01') [Synset('entity.n.01')]
# Synset('dodge.n.02') [Synset('entity.n.01')]
# Synset('break.n.16') [Synset('entity.n.01')]
# Synset('getaway.n.02') [Synset('entity.n.01')]
# Synset('exodus.n.01') [Synset('entity.n.01')]
# Synset('hegira.n.01') [Synset('entity.n.01')]
# Synset('skedaddle.n.01') [Synset('entity.n.01')]
# Synset('underground_railroad.n.01') [Synset('entity.n.01')]
# Synset('close_call.n.01') [Synset('entity.n.01')]
# Synset('surfacing.n.01') [Synset('entity.n.01')]
# Synset('dispatch.n.02') [Synset('entity.n.01')]
# Synset('reshipment.n.01') [Synset('entity.n.01')]
# Synset('consummation.n.02') [Synset('entity.n.01')]
# Synset('consummation.n.01') [Synset('entity.n.01')]
# Synset('realization.n.06') [Synset('entity.n.01')]
# Synset('orgasm.n.01') [Synset('entity.n.01')]
# Synset('male_orgasm.n.01') [Synset('entity.n.01')]
# Synset('fulfillment.n.02') [Synset('entity.n.01')]
# Synset('self-fulfillment.n.01') [Synset('entity.n.01')]
# Synset('attainment.n.01') [Synset('entity.n.01')]
# Synset('record.n.06') [Synset('entity.n.01')]
# Synset('track_record.n.01') [Synset('entity.n.01')]
# Synset('world_record.n.01') [Synset('entity.n.01')]
# Synset('success.n.02') [Synset('entity.n.01')]
# Synset('winning.n.01') [Synset('entity.n.01')]
# Synset('blockbuster.n.02') [Synset('entity.n.01')]
# Synset('sleeper.n.09') [Synset('entity.n.01')]
# Synset('hit.n.03') [Synset('entity.n.01')]
# Synset('bell_ringer.n.03') [Synset('entity.n.01')]
# Synset('ennoblement.n.02') [Synset('entity.n.01')]
# Synset('conquest.n.02') [Synset('entity.n.01')]
# Synset('coup.n.02') [Synset('entity.n.01')]
# Synset('flying_colors.n.01') [Synset('entity.n.01')]
# Synset('passing.n.07') [Synset('entity.n.01')]
# Synset('credit.n.06') [Synset('entity.n.01')]
# Synset('semester_hour.n.01') [Synset('entity.n.01')]
# Synset('nonaccomplishment.n.01') [Synset('entity.n.01')]
# Synset('failure.n.05') [Synset('entity.n.01')]
# Synset('failure.n.01') [Synset('entity.n.01')]
# Synset('failing.n.02') [Synset('entity.n.01')]
# Synset('naught.n.02') [Synset('entity.n.01')]
# Synset('cut.n.20') [Synset('entity.n.01')]
# Synset('default.n.01') [Synset('entity.n.01')]
# Synset('loss.n.03') [Synset('entity.n.01')]
# Synset('capitulation.n.03') [Synset('entity.n.01')]
# Synset('frustration.n.02') [Synset('entity.n.01')]
# Synset('overturn.n.02') [Synset('entity.n.01')]
# Synset('backsliding.n.01') [Synset('entity.n.01')]
# Synset('recidivism.n.01') [Synset('entity.n.01')]
# Synset('disappointment.n.02') [Synset('entity.n.01')]
# Synset('breach.n.01') [Synset('entity.n.01')]
# Synset('copout.n.01') [Synset('entity.n.01')]
# Synset('breach_of_contract.n.01') [Synset('entity.n.01')]
# Synset('anticipatory_breach.n.01') [Synset('entity.n.01')]
# Synset('breach_of_duty.n.01') [Synset('entity.n.01')]
# Synset('breach_of_the_covenant_of_warranty.n.01') [Synset('entity.n.01')]
# Synset('breach_of_promise.n.01') [Synset('entity.n.01')]
# Synset('breach_of_trust.n.01') [Synset('entity.n.01')]
# Synset('breach_of_trust_with_fraudulent_intent.n.01') [Synset('entity.n.01')]
# Synset('breach_of_warranty.n.01') [Synset('entity.n.01')]
# Synset('leaning.n.04') [Synset('entity.n.01')]
# Synset('material_breach.n.01') [Synset('entity.n.01')]
# Synset('motivation.n.03') [Synset('entity.n.01')]
# Synset('partial_breach.n.01') [Synset('entity.n.01')]
# Synset('mistake.n.01') [Synset('entity.n.01')]
# Synset('double_fault.n.01') [Synset('entity.n.01')]
# Synset('footfault.n.01') [Synset('entity.n.01')]
# Synset('bobble.n.01') [Synset('entity.n.01')]
# Synset('error.n.04') [Synset('entity.n.01')]
# Synset('blot.n.02') [Synset('entity.n.01')]
# Synset('confusion.n.05') [Synset('entity.n.01')]
# Synset('incursion.n.03') [Synset('entity.n.01')]
# Synset('miscalculation.n.01') [Synset('entity.n.01')]
# Synset('backfire.n.04') [Synset('entity.n.01')]
# Synset('rounding.n.01') [Synset('entity.n.01')]
# Synset('truncation_error.n.01') [Synset('entity.n.01')]
# Synset('distortion.n.06') [Synset('entity.n.01')]
# Synset('slip.n.02') [Synset('entity.n.01')]
# Synset('freudian_slip.n.01') [Synset('entity.n.01')]
# Synset('offside.n.01') [Synset('entity.n.01')]
# Synset('oversight.n.03') [Synset('entity.n.01')]
# Synset('omission.n.01') [Synset('entity.n.01')]
# Synset('blunder.n.01') [Synset('entity.n.01')]
# Synset('snafu.n.01') [Synset('entity.n.01')]
# Synset('spectacle.n.03') [Synset('entity.n.01')]
# Synset('ballup.n.01') [Synset('entity.n.01')]
# Synset('bull.n.04') [Synset('entity.n.01')]
# Synset('fumble.n.01') [Synset('entity.n.01')]
# Synset('fluff.n.03') [Synset('entity.n.01')]
# Synset('faux_pas.n.01') [Synset('entity.n.01')]
# Synset('howler.n.03') [Synset('entity.n.01')]
# Synset('clanger.n.01') [Synset('entity.n.01')]
# Synset('trip.n.07') [Synset('entity.n.01')]
# Synset('spill.n.04') [Synset('entity.n.01')]
# Synset('pratfall.n.01') [Synset('entity.n.01')]
# Synset('wipeout.n.02') [Synset('entity.n.01')]
# Synset('acquisition.n.01') [Synset('entity.n.01')]
# Synset('obtainment.n.01') [Synset('entity.n.01')]
# Synset('catching.n.03') [Synset('entity.n.01')]
# Synset('incurring.n.01') [Synset('entity.n.01')]
# Synset('moneymaking.n.01') [Synset('entity.n.01')]
# Synset('annexation.n.02') [Synset('entity.n.01')]
# Synset('pork-barreling.n.01') [Synset('entity.n.01')]
# Synset('purchase.n.01') [Synset('entity.n.01')]
# Synset('redemption.n.03') [Synset('entity.n.01')]
# Synset('trading.n.01') [Synset('entity.n.01')]
# Synset('bond_trading.n.01') [Synset('entity.n.01')]
# Synset('program_trading.n.01') [Synset('entity.n.01')]
# Synset('short_sale.n.01') [Synset('entity.n.01')]
# Synset('short_covering.n.01') [Synset('entity.n.01')]
# Synset('insider_trading.n.01') [Synset('entity.n.01')]
# Synset('naked_option.n.01') [Synset('entity.n.01')]
# Synset('covered_option.n.01') [Synset('entity.n.01')]
# Synset('call_option.n.02') [Synset('entity.n.01')]
# Synset('put_option.n.02') [Synset('entity.n.01')]
# Synset('straddle.n.04') [Synset('entity.n.01')]
# Synset('incentive_option.n.01') [Synset('entity.n.01')]
# Synset('buying.n.01') [Synset('entity.n.01')]
# Synset('shopping.n.01') [Synset('entity.n.01')]
# Synset('marketing.n.03') [Synset('entity.n.01')]
# Synset('mail-order_buying.n.01') [Synset('entity.n.01')]
# Synset('viatication.n.01') [Synset('entity.n.01')]
# Synset('acceptance.n.07') [Synset('entity.n.01')]
# Synset('succession.n.05') [Synset('entity.n.01')]
# Synset('assumption.n.03') [Synset('entity.n.01')]
# Synset('assumption.n.07') [Synset('entity.n.01')]
# Synset('position.n.16') [Synset('entity.n.01')]
# Synset('inheritance.n.01') [Synset('entity.n.01')]
# Synset('procurement.n.01') [Synset('entity.n.01')]
# Synset('appropriation.n.03') [Synset('entity.n.01')]
# Synset('borrowing.n.01') [Synset('entity.n.01')]
# Synset('naturalization.n.04') [Synset('entity.n.01')]
# Synset('misappropriation.n.02') [Synset('entity.n.01')]
# Synset('preemption.n.04') [Synset('entity.n.01')]
# Synset('seizure.n.04') [Synset('entity.n.01')]
# Synset('usurpation.n.02') [Synset('entity.n.01')]
# Synset('confiscation.n.01') [Synset('entity.n.01')]
# Synset('distress.n.04') [Synset('entity.n.01')]
# Synset('expropriation.n.01') [Synset('entity.n.01')]
# Synset('impoundment.n.01') [Synset('entity.n.01')]
# Synset('drug_bust.n.01') [Synset('entity.n.01')]
# Synset('impress.n.01') [Synset('entity.n.01')]
# Synset('occupation.n.04') [Synset('entity.n.01')]
# Synset('preoccupancy.n.02') [Synset('entity.n.01')]
# Synset('sequestration.n.04') [Synset('entity.n.01')]
# Synset('grant.n.02') [Synset('entity.n.01')]
# Synset('award.n.01') [Synset('entity.n.01')]
# Synset('addiction.n.03') [Synset('entity.n.01')]
# Synset('block_grant.n.01') [Synset('entity.n.01')]
# Synset('grant-in-aid.n.01') [Synset('entity.n.01')]
# Synset('capture.n.01') [Synset('entity.n.01')]
# Synset('apprehension.n.04') [Synset('entity.n.01')]
# Synset('conquest.n.01') [Synset('entity.n.01')]
# Synset('enslavement.n.02') [Synset('entity.n.01')]
# Synset('restitution.n.03') [Synset('entity.n.01')]
# Synset('clawback.n.01') [Synset('entity.n.01')]
# Synset('repossession.n.01') [Synset('entity.n.01')]
# Synset('foreclosure.n.01') [Synset('entity.n.01')]
# Synset('reception.n.04') [Synset('entity.n.01')]
# Synset('appointment.n.06') [Synset('entity.n.01')]
# Synset('comb-out.n.02') [Synset('entity.n.01')]
# Synset('giving.n.03') [Synset('entity.n.01')]
# Synset('abandonment.n.03') [Synset('entity.n.01')]
# Synset('discard.n.03') [Synset('entity.n.01')]
# Synset('staging.n.04') [Synset('entity.n.01')]
# Synset('discard.n.02') [Synset('entity.n.01')]
# Synset('mine_disposal.n.01') [Synset('entity.n.01')]
# Synset('minesweeping.n.01') [Synset('entity.n.01')]
# Synset('sewage_disposal.n.01') [Synset('entity.n.01')]
# Synset('bait_and_switch.n.01') [Synset('entity.n.01')]
# Synset('private_treaty.n.01') [Synset('entity.n.01')]
# Synset('auction.n.02') [Synset('entity.n.01')]
# Synset('bootlegging.n.01') [Synset('entity.n.01')]
# Synset('bootlegging.n.02') [Synset('entity.n.01')]
# Synset('capitalization.n.04') [Synset('entity.n.01')]
# Synset('overcapitalization.n.01') [Synset('entity.n.01')]
# Synset('reclamation.n.03') [Synset('entity.n.01')]
# Synset('rescue.n.01') [Synset('entity.n.01')]
# Synset('lifesaving.n.01') [Synset('entity.n.01')]
# Synset('redemption.n.01') [Synset('entity.n.01')]
# Synset('absolution.n.02') [Synset('entity.n.01')]
# Synset('indulgence.n.05') [Synset('entity.n.01')]
# Synset('conversion.n.04') [Synset('entity.n.01')]
# Synset('proselytism.n.02') [Synset('entity.n.01')]
# Synset('expiation.n.02') [Synset('entity.n.01')]
# Synset('reparation.n.04') [Synset('entity.n.01')]
# Synset('liberation.n.01') [Synset('entity.n.01')]
# Synset('jail_delivery.n.01') [Synset('entity.n.01')]
# Synset('reclamation.n.02') [Synset('entity.n.01')]
# Synset('salvage.n.03') [Synset('entity.n.01')]
# Synset('salvage.n.02') [Synset('entity.n.01')]
# Synset('salvation.n.04') [Synset('entity.n.01')]
# Synset('search_and_rescue_mission.n.01') [Synset('entity.n.01')]
# Synset('ransom.n.03') [Synset('entity.n.01')]
# Synset('recapture.n.02') [Synset('entity.n.01')]
# Synset('recapture.n.01') [Synset('entity.n.01')]
# Synset('invocation.n.04') [Synset('entity.n.01')]
# Synset('instrumentation.n.02') [Synset('entity.n.01')]
# Synset('performance.n.03') [Synset('entity.n.01')]
# Synset('specific_performance.n.01') [Synset('entity.n.01')]
# Synset('linguistic_performance.n.01') [Synset('entity.n.01')]
# Synset('mechanism.n.02') [Synset('entity.n.01')]
# Synset('service.n.15') [Synset('entity.n.01')]
# Synset('curb_service.n.01') [Synset('entity.n.01')]
# Synset('self-service.n.01') [Synset('entity.n.01')]
# Synset('valet_parking.n.01') [Synset('entity.n.01')]
# Synset('dramatic_production.n.01') [Synset('entity.n.01')]
# Synset('encore.n.01') [Synset('entity.n.01')]
# Synset('extemporization.n.01') [Synset('entity.n.01')]
# Synset('juggle.n.02') [Synset('entity.n.01')]
# Synset('magic_trick.n.01') [Synset('entity.n.01')]
# Synset('musical_performance.n.01') [Synset('entity.n.01')]
# Synset('one-night_stand.n.02') [Synset('entity.n.01')]
# Synset('rendition.n.04') [Synset('entity.n.01')]
# Synset('reinterpretation.n.02') [Synset('entity.n.01')]
# Synset('spin.n.05') [Synset('entity.n.01')]
# Synset('playing.n.01') [Synset('entity.n.01')]
# Synset('bowing.n.02') [Synset('entity.n.01')]
# Synset('spiccato.n.01') [Synset('entity.n.01')]
# Synset('piping.n.03') [Synset('entity.n.01')]
# Synset('stopping.n.02') [Synset('entity.n.01')]
# Synset('double_stopping.n.01') [Synset('entity.n.01')]
# Synset('transposition.n.07') [Synset('entity.n.01')]
# Synset('jam_session.n.01') [Synset('entity.n.01')]
# Synset('automation.n.01') [Synset('entity.n.01')]
# Synset('computerization.n.01') [Synset('entity.n.01')]
# Synset('motorization.n.01') [Synset('entity.n.01')]
# Synset('launching.n.03') [Synset('entity.n.01')]
# Synset('launching.n.01') [Synset('entity.n.01')]
# Synset('rocket_firing.n.01') [Synset('entity.n.01')]
# Synset('blastoff.n.01') [Synset('entity.n.01')]
# Synset('moon_shot.n.01') [Synset('entity.n.01')]
# Synset('drive.n.01') [Synset('entity.n.01')]
# Synset('firewall.n.01') [Synset('entity.n.01')]
# Synset('impulse.n.05') [Synset('entity.n.01')]
# Synset('roll.n.15') [Synset('entity.n.01')]
# Synset('throw.n.01') [Synset('entity.n.01')]
# Synset('bowling.n.02') [Synset('entity.n.01')]
# Synset('fling.n.03') [Synset('entity.n.01')]
# Synset('heave.n.06') [Synset('entity.n.01')]
# Synset('hurl.n.01') [Synset('entity.n.01')]
# Synset('leaner.n.01') [Synset('entity.n.01')]
# Synset('pass.n.15') [Synset('entity.n.01')]
# Synset('pitch.n.10') [Synset('entity.n.01')]
# Synset('pitch.n.02') [Synset('entity.n.01')]
# Synset('ringer.n.04') [Synset('entity.n.01')]
# Synset('shy.n.01') [Synset('entity.n.01')]
# Synset('slinging.n.01') [Synset('entity.n.01')]
# Synset('throw-in.n.01') [Synset('entity.n.01')]
# Synset('balk.n.04') [Synset('entity.n.01')]
# Synset('ball.n.12') [Synset('entity.n.01')]
# Synset('beanball.n.01') [Synset('entity.n.01')]
# Synset('change-up.n.01') [Synset('entity.n.01')]
# Synset('curve.n.03') [Synset('entity.n.01')]
# Synset('duster.n.04') [Synset('entity.n.01')]
# Synset('fastball.n.01') [Synset('entity.n.01')]
# Synset('knuckleball.n.01') [Synset('entity.n.01')]
# Synset('overhand_pitch.n.01') [Synset('entity.n.01')]
# Synset('passed_ball.n.01') [Synset('entity.n.01')]
# Synset('screwball.n.02') [Synset('entity.n.01')]
# Synset('sinker.n.03') [Synset('entity.n.01')]
# Synset('slider.n.04') [Synset('entity.n.01')]
# Synset('spitball.n.02') [Synset('entity.n.01')]
# Synset('strike.n.05') [Synset('entity.n.01')]
# Synset('submarine_ball.n.01') [Synset('entity.n.01')]
# Synset('wild_pitch.n.01') [Synset('entity.n.01')]
# Synset('basketball_shot.n.01') [Synset('entity.n.01')]
# Synset('bank_shot.n.01') [Synset('entity.n.01')]
# Synset('dunk.n.01') [Synset('entity.n.01')]
# Synset('slam_dunk.n.02') [Synset('entity.n.01')]
# Synset('finger-roll.n.01') [Synset('entity.n.01')]
# Synset('foul_shot.n.01') [Synset('entity.n.01')]
# Synset('one-and-one.n.01') [Synset('entity.n.01')]
# Synset('hook_shot.n.01') [Synset('entity.n.01')]
# Synset('jumper.n.08') [Synset('entity.n.01')]
# Synset('lay-up.n.01') [Synset('entity.n.01')]
# Synset('pivot_shot.n.01') [Synset('entity.n.01')]
# Synset('set_shot.n.01') [Synset('entity.n.01')]
# Synset('scoop_shot.n.01') [Synset('entity.n.01')]
# Synset('tip_in.n.01') [Synset('entity.n.01')]
# Synset('push.n.01') [Synset('entity.n.01')]
# Synset('depression.n.10') [Synset('entity.n.01')]
# Synset('click.n.04') [Synset('entity.n.01')]
# Synset('nudge.n.01') [Synset('entity.n.01')]
# Synset('press.n.09') [Synset('entity.n.01')]
# Synset('impression.n.09') [Synset('entity.n.01')]
# Synset('shove.n.01') [Synset('entity.n.01')]
# Synset('bundling.n.03') [Synset('entity.n.01')]
# Synset('jostle.n.01') [Synset('entity.n.01')]
# Synset('elbowing.n.01') [Synset('entity.n.01')]
# Synset('pull.n.01') [Synset('entity.n.01')]
# Synset('drag.n.06') [Synset('entity.n.01')]
# Synset('draw.n.09') [Synset('entity.n.01')]
# Synset('tow.n.01') [Synset('entity.n.01')]
# Synset('tug.n.01') [Synset('entity.n.01')]
# Synset('draft.n.11') [Synset('entity.n.01')]
# Synset('extirpation.n.02') [Synset('entity.n.01')]
# Synset('pluck.n.02') [Synset('entity.n.01')]
# Synset('traction.n.02') [Synset('entity.n.01')]
# Synset('lift.n.12') [Synset('entity.n.01')]
# Synset('expulsion.n.03') [Synset('entity.n.01')]
# Synset('defenestration.n.01') [Synset('entity.n.01')]
# Synset('accommodation_reflex.n.01') [Synset('entity.n.01')]
# Synset('babinski.n.01') [Synset('entity.n.01')]
# Synset('belch.n.01') [Synset('entity.n.01')]
# Synset('belching.n.01') [Synset('entity.n.01')]
# Synset('blink.n.01') [Synset('entity.n.01')]
# Synset('blush.n.02') [Synset('entity.n.01')]
# Synset('coughing_up.n.01') [Synset('entity.n.01')]
# Synset('spit.n.04') [Synset('entity.n.01')]
# Synset('vomit.n.03') [Synset('entity.n.01')]
# Synset('rumination.n.03') [Synset('entity.n.01')]
# Synset('hematemesis.n.01') [Synset('entity.n.01')]
# Synset('hyperemesis.n.01') [Synset('entity.n.01')]
# Synset('hyperemesis_gravidarum.n.01') [Synset('entity.n.01')]
# Synset('jump.n.06') [Synset('entity.n.01')]
# Synset('header.n.07') [Synset('entity.n.01')]
# Synset('hop.n.01') [Synset('entity.n.01')]
# Synset('leap.n.01') [Synset('entity.n.01')]
# Synset('vault.n.04') [Synset('entity.n.01')]
# Synset('jumping_up_and_down.n.01') [Synset('entity.n.01')]
# Synset('lob.n.02') [Synset('entity.n.01')]
# Synset('centering.n.02') [Synset('entity.n.01')]
# Synset('sending.n.01') [Synset('entity.n.01')]
# Synset('transmission.n.01') [Synset('entity.n.01')]
# Synset('forwarding.n.01') [Synset('entity.n.01')]
# Synset('referral.n.03') [Synset('entity.n.01')]
# Synset('remission.n.03') [Synset('entity.n.01')]
# Synset('mailing.n.02') [Synset('entity.n.01')]
# Synset('wheeling.n.02') [Synset('entity.n.01')]
# Synset('shooting.n.01') [Synset('entity.n.01')]
# Synset('shoot.n.02') [Synset('entity.n.01')]
# Synset('countershot.n.01') [Synset('entity.n.01')]
# Synset('discharge.n.09') [Synset('entity.n.01')]
# Synset('gun.n.07') [Synset('entity.n.01')]
# Synset('fire_control.n.01') [Synset('entity.n.01')]
# Synset('gunfire.n.01') [Synset('entity.n.01')]
# Synset('enfilade.n.01') [Synset('entity.n.01')]
# Synset('snipe.n.02') [Synset('entity.n.01')]
# Synset('headshot.n.03') [Synset('entity.n.01')]
# Synset('skeet.n.01') [Synset('entity.n.01')]
# Synset('shellfire.n.01') [Synset('entity.n.01')]
# Synset('gunfight.n.01') [Synset('entity.n.01')]
# Synset('potshot.n.01') [Synset('entity.n.01')]
# Synset('contact.n.02') [Synset('entity.n.01')]
# Synset('rub.n.02') [Synset('entity.n.01')]
# Synset('scuff.n.02') [Synset('entity.n.01')]
# Synset('tap.n.08') [Synset('entity.n.01')]
# Synset('hit.n.02') [Synset('entity.n.01')]
# Synset('contusion.n.02') [Synset('entity.n.01')]
# Synset('crash.n.04') [Synset('entity.n.01')]
# Synset('impingement.n.02') [Synset('entity.n.01')]
# Synset('batting.n.01') [Synset('entity.n.01')]
# Synset('fielding.n.01') [Synset('entity.n.01')]
# Synset('catching.n.01') [Synset('entity.n.01')]
# Synset('golfing.n.01') [Synset('entity.n.01')]
# Synset('pitching.n.01') [Synset('entity.n.01')]
# Synset('base_on_balls.n.01') [Synset('entity.n.01')]
# Synset('best.n.01') [Synset('entity.n.01')]
# Synset('worst.n.03') [Synset('entity.n.01')]
# Synset('fair_ball.n.01') [Synset('entity.n.01')]
# Synset('foul_ball.n.01') [Synset('entity.n.01')]
# Synset('snick.n.02') [Synset('entity.n.01')]
# Synset('bunt.n.01') [Synset('entity.n.01')]
# Synset('fly.n.04') [Synset('entity.n.01')]
# Synset('blast.n.01') [Synset('entity.n.01')]
# Synset('pop_fly.n.01') [Synset('entity.n.01')]
# Synset('grounder.n.01') [Synset('entity.n.01')]
# Synset('chop.n.05') [Synset('entity.n.01')]
# Synset('roller.n.01') [Synset('entity.n.01')]
# Synset('out.n.01') [Synset('entity.n.01')]
# Synset('force_out.n.01') [Synset('entity.n.01')]
# Synset('putout.n.01') [Synset('entity.n.01')]
# Synset('strikeout.n.01') [Synset('entity.n.01')]
# Synset('whiff.n.03') [Synset('entity.n.01')]
# Synset('fielder's_choice.n.01') [Synset('entity.n.01')]
# Synset('sacrifice.n.05') [Synset('entity.n.01')]
# Synset('sacrifice_fly.n.01') [Synset('entity.n.01')]
# Synset('base_hit.n.01') [Synset('entity.n.01')]
# Synset('daisy_cutter.n.02') [Synset('entity.n.01')]
# Synset('header.n.06') [Synset('entity.n.01')]
# Synset('liner.n.01') [Synset('entity.n.01')]
# Synset('scorcher.n.02') [Synset('entity.n.01')]
# Synset('line-drive_single.n.01') [Synset('entity.n.01')]
# Synset('line-drive_double.n.01') [Synset('entity.n.01')]
# Synset('line-drive_triple.n.01') [Synset('entity.n.01')]
# Synset('plunk.n.02') [Synset('entity.n.01')]
# Synset('homer.n.01') [Synset('entity.n.01')]
# Synset('solo_homer.n.01') [Synset('entity.n.01')]
# Synset('single.n.01') [Synset('entity.n.01')]
# Synset('double.n.01') [Synset('entity.n.01')]
# Synset('triple.n.01') [Synset('entity.n.01')]
# Synset('backhander.n.01') [Synset('entity.n.01')]
# Synset('clip.n.06') [Synset('entity.n.01')]
# Synset('knock.n.05') [Synset('entity.n.01')]
# Synset('thwack.n.01') [Synset('entity.n.01')]
# Synset('smack.n.06') [Synset('entity.n.01')]
# Synset('smacker.n.02') [Synset('entity.n.01')]
# Synset('knockdown.n.01') [Synset('entity.n.01')]
# Synset('knockout.n.02') [Synset('entity.n.01')]
# Synset('technical_knockout.n.01') [Synset('entity.n.01')]
# Synset('swat.n.01') [Synset('entity.n.01')]
# Synset('spank.n.01') [Synset('entity.n.01')]
# Synset('whip.n.05') [Synset('entity.n.01')]
# Synset('punch.n.01') [Synset('entity.n.01')]
# Synset('box.n.10') [Synset('entity.n.01')]
# Synset('dig.n.05') [Synset('entity.n.01')]
# Synset('counterpunch.n.01') [Synset('entity.n.01')]
# Synset('haymaker.n.02') [Synset('entity.n.01')]
# Synset('hook.n.07') [Synset('entity.n.01')]
# Synset('jab.n.02') [Synset('entity.n.01')]
# Synset('rabbit_punch.n.01') [Synset('entity.n.01')]
# Synset('sucker_punch.n.01') [Synset('entity.n.01')]
# Synset('roundhouse.n.02') [Synset('entity.n.01')]
# Synset('kick.n.01') [Synset('entity.n.01')]
# Synset('goal-kick.n.02') [Synset('entity.n.01')]
# Synset('goal-kick.n.01') [Synset('entity.n.01')]
# Synset('punt.n.03') [Synset('entity.n.01')]
# Synset('place_kick.n.01') [Synset('entity.n.01')]
# Synset('free_kick.n.01') [Synset('entity.n.01')]
# Synset('corner_kick.n.01') [Synset('entity.n.01')]
# Synset('dropkick.n.01') [Synset('entity.n.01')]
# Synset('kiss.n.04') [Synset('entity.n.01')]
# Synset('kiss.n.01') [Synset('entity.n.01')]
# Synset('laying_on.n.01') [Synset('entity.n.01')]
# Synset('smack.n.05') [Synset('entity.n.01')]
# Synset('smacker.n.01') [Synset('entity.n.01')]
# Synset('soul_kiss.n.01') [Synset('entity.n.01')]
# Synset('catch.n.09') [Synset('entity.n.01')]
# Synset('fair_catch.n.01') [Synset('entity.n.01')]
# Synset('interception.n.02') [Synset('entity.n.01')]
# Synset('reception.n.05') [Synset('entity.n.01')]
# Synset('rebound.n.03') [Synset('entity.n.01')]
# Synset('shoestring_catch.n.01') [Synset('entity.n.01')]
# Synset('mesh.n.05') [Synset('entity.n.01')]
# Synset('handling.n.02') [Synset('entity.n.01')]
# Synset('fingering.n.02') [Synset('entity.n.01')]
# Synset('grope.n.01') [Synset('entity.n.01')]
# Synset('audit.n.02') [Synset('entity.n.01')]
# Synset('autopsy.n.01') [Synset('entity.n.01')]
# Synset('check-in.n.01') [Synset('entity.n.01')]
# Synset('check.n.06') [Synset('entity.n.01')]
# Synset('spot_check.n.01') [Synset('entity.n.01')]
# Synset('checkup.n.01') [Synset('entity.n.01')]
# Synset('comparison.n.01') [Synset('entity.n.01')]
# Synset('fine-tooth_comb.n.02') [Synset('entity.n.01')]
# Synset('follow-up.n.03') [Synset('entity.n.01')]
# Synset('going-over.n.01') [Synset('entity.n.01')]
# Synset('once-over.n.01') [Synset('entity.n.01')]
# Synset('ophthalmoscopy.n.01') [Synset('entity.n.01')]
# Synset('palpation.n.01') [Synset('entity.n.01')]
# Synset('ballottement.n.01') [Synset('entity.n.01')]
# Synset('tickle.n.02') [Synset('entity.n.01')]
# Synset('stroke.n.05') [Synset('entity.n.01')]
# Synset('caress.n.01') [Synset('entity.n.01')]
# Synset('tag.n.05') [Synset('entity.n.01')]
# Synset('joining.n.01') [Synset('entity.n.01')]
# Synset('hit.n.07') [Synset('entity.n.01')]
# Synset('interconnection.n.02') [Synset('entity.n.01')]
# Synset('intersection.n.06') [Synset('entity.n.01')]
# Synset('approximation.n.04') [Synset('entity.n.01')]
# Synset('concatenation.n.04') [Synset('entity.n.01')]
# Synset('convergence.n.04') [Synset('entity.n.01')]
# Synset('merging.n.01') [Synset('entity.n.01')]
# Synset('concourse.n.03') [Synset('entity.n.01')]
# Synset('encounter.n.03') [Synset('entity.n.01')]
# Synset('articulation.n.05') [Synset('entity.n.01')]
# Synset('junction.n.05') [Synset('entity.n.01')]
# Synset('fastening.n.02') [Synset('entity.n.01')]
# Synset('loosening.n.02') [Synset('entity.n.01')]
# Synset('tightening.n.01') [Synset('entity.n.01')]
# Synset('ligation.n.01') [Synset('entity.n.01')]
# Synset('tubal_ligation.n.01') [Synset('entity.n.01')]
# Synset('bonding.n.03') [Synset('entity.n.01')]
# Synset('doweling.n.01') [Synset('entity.n.01')]
# Synset('grounding.n.02') [Synset('entity.n.01')]
# Synset('linkage.n.04') [Synset('entity.n.01')]
# Synset('tying.n.01') [Synset('entity.n.01')]
# Synset('untying.n.01') [Synset('entity.n.01')]
# Synset('welding.n.01') [Synset('entity.n.01')]
# Synset('butt_welding.n.01') [Synset('entity.n.01')]
# Synset('spot_welding.n.01') [Synset('entity.n.01')]
# Synset('flare.n.11') [Synset('entity.n.01')]
# Synset('texas_leaguer.n.01') [Synset('entity.n.01')]
# Synset('flash_welding.n.01') [Synset('entity.n.01')]
# Synset('lick.n.02') [Synset('entity.n.01')]
# Synset('grazing.n.02') [Synset('entity.n.01')]
# Synset('tracing.n.03') [Synset('entity.n.01')]
# Synset('detection.n.02') [Synset('entity.n.01')]
# Synset('self-discovery.n.01') [Synset('entity.n.01')]
# Synset('breakthrough.n.02') [Synset('entity.n.01')]
# Synset('determination.n.01') [Synset('entity.n.01')]
# Synset('rediscovery.n.01') [Synset('entity.n.01')]
# Synset('designation.n.03') [Synset('entity.n.01')]
# Synset('bertillon_system.n.01') [Synset('entity.n.01')]
# Synset('fingerprinting.n.01') [Synset('entity.n.01')]
# Synset('genetic_profiling.n.01') [Synset('entity.n.01')]
# Synset('diagnosis.n.01') [Synset('entity.n.01')]
# Synset('blood_typing.n.01') [Synset('entity.n.01')]
# Synset('medical_diagnosis.n.01') [Synset('entity.n.01')]
# Synset('prenatal_diagnosis.n.01') [Synset('entity.n.01')]
# Synset('differential_diagnosis.n.01') [Synset('entity.n.01')]
# Synset('prognosis.n.02') [Synset('entity.n.01')]
# Synset('resolution.n.04') [Synset('entity.n.01')]
# Synset('validation.n.01') [Synset('entity.n.01')]
# Synset('authentication.n.02') [Synset('entity.n.01')]
# Synset('documentation.n.03') [Synset('entity.n.01')]
# Synset('monetization.n.01') [Synset('entity.n.01')]
# Synset('probate.n.02') [Synset('entity.n.01')]
# Synset('demonetization.n.01') [Synset('entity.n.01')]
# Synset('falsification.n.04') [Synset('entity.n.01')]
# Synset('localization.n.01') [Synset('entity.n.01')]
# Synset('echolocation.n.01') [Synset('entity.n.01')]
# Synset('predetermination.n.03') [Synset('entity.n.01')]
# Synset('rectification.n.04') [Synset('entity.n.01')]
# Synset('redetermination.n.01') [Synset('entity.n.01')]
# Synset('trigger.n.03') [Synset('entity.n.01')]
# Synset('fomentation.n.03') [Synset('entity.n.01')]
# Synset('compulsion.n.03') [Synset('entity.n.01')]
# Synset('influence.n.02') [Synset('entity.n.01')]
# Synset('cross-pollination.n.02') [Synset('entity.n.01')]
# Synset('exposure.n.02') [Synset('entity.n.01')]
# Synset('overexposure.n.02') [Synset('entity.n.01')]
# Synset('underexposure.n.02') [Synset('entity.n.01')]
# Synset('impingement.n.01') [Synset('entity.n.01')]
# Synset('manipulation.n.01') [Synset('entity.n.01')]
# Synset('mind_game.n.02') [Synset('entity.n.01')]
# Synset('autosuggestion.n.01') [Synset('entity.n.01')]
# Synset('hypnotism.n.01') [Synset('entity.n.01')]
# Synset('inducement.n.02') [Synset('entity.n.01')]
# Synset('corruption.n.06') [Synset('entity.n.01')]
# Synset('enticement.n.03') [Synset('entity.n.01')]
# Synset('blandishment.n.02') [Synset('entity.n.01')]
# Synset('ingratiation.n.01') [Synset('entity.n.01')]
# Synset('leading_astray.n.01') [Synset('entity.n.01')]
# Synset('seduction.n.01') [Synset('entity.n.01')]
# Synset('seduction.n.02') [Synset('entity.n.01')]
# Synset('sexual_conquest.n.01') [Synset('entity.n.01')]
# Synset('cuckoldry.n.01') [Synset('entity.n.01')]
# Synset('solicitation.n.03') [Synset('entity.n.01')]
# Synset('choice.n.02') [Synset('entity.n.01')]
# Synset('casting.n.04') [Synset('entity.n.01')]
# Synset('coloration.n.03') [Synset('entity.n.01')]
# Synset('sampling.n.01') [Synset('entity.n.01')]
# Synset('random_sampling.n.01') [Synset('entity.n.01')]
# Synset('lucky_dip.n.02') [Synset('entity.n.01')]
# Synset('stratified_sampling.n.01') [Synset('entity.n.01')]
# Synset('decision.n.01') [Synset('entity.n.01')]
# Synset('volition.n.02') [Synset('entity.n.01')]
# Synset('intention.n.03') [Synset('entity.n.01')]
# Synset('about-face.n.02') [Synset('entity.n.01')]
# Synset('adulteration.n.02') [Synset('entity.n.01')]
# Synset('appointment.n.01') [Synset('entity.n.01')]
# Synset('nomination.n.01') [Synset('entity.n.01')]
# Synset('assignment.n.03') [Synset('entity.n.01')]
# Synset('allocation.n.03') [Synset('entity.n.01')]
# Synset('call.n.12') [Synset('entity.n.01')]
# Synset('co-option.n.02') [Synset('entity.n.01')]
# Synset('delegacy.n.03') [Synset('entity.n.01')]
# Synset('ordination.n.03') [Synset('entity.n.01')]
# Synset('recognition.n.08') [Synset('entity.n.01')]
# Synset('laying_on_of_hands.n.02') [Synset('entity.n.01')]
# Synset('move.n.01') [Synset('entity.n.01')]
# Synset('move.n.05') [Synset('entity.n.01')]
# Synset('chess_move.n.01') [Synset('entity.n.01')]
# Synset('castle.n.04') [Synset('entity.n.01')]
# Synset('capture.n.05') [Synset('entity.n.01')]
# Synset('en_passant.n.01') [Synset('entity.n.01')]
# Synset('exchange.n.11') [Synset('entity.n.01')]
# Synset('exchange.n.10') [Synset('entity.n.01')]
# Synset('check.n.13') [Synset('entity.n.01')]
# Synset('discovered_check.n.01') [Synset('entity.n.01')]
# Synset('checkmate.n.02') [Synset('entity.n.01')]
# Synset('gambit.n.03') [Synset('entity.n.01')]
# Synset('demarche.n.01') [Synset('entity.n.01')]
# Synset('maneuver.n.04') [Synset('entity.n.01')]
# Synset('parking.n.02') [Synset('entity.n.01')]
# Synset('move.n.02') [Synset('entity.n.01')]
# Synset('flit.n.02') [Synset('entity.n.01')]
# Synset('downshift.n.02') [Synset('entity.n.01')]
# Synset('downshift.n.01') [Synset('entity.n.01')]
# Synset('bank.n.10') [Synset('entity.n.01')]
# Synset('vertical_bank.n.01') [Synset('entity.n.01')]
# Synset('chandelle.n.01') [Synset('entity.n.01')]
# Synset('loop.n.10') [Synset('entity.n.01')]
# Synset('inside_loop.n.01') [Synset('entity.n.01')]
# Synset('outside_loop.n.01') [Synset('entity.n.01')]
# Synset('roll.n.14') [Synset('entity.n.01')]
# Synset('barrel_roll.n.01') [Synset('entity.n.01')]
# Synset('snap_roll.n.01') [Synset('entity.n.01')]
# Synset('slip.n.14') [Synset('entity.n.01')]
# Synset('flight_maneuver.n.01') [Synset('entity.n.01')]
# Synset('straight-arm.n.01') [Synset('entity.n.01')]
# Synset('device.n.03') [Synset('entity.n.01')]
# Synset('mnemonic.n.01') [Synset('entity.n.01')]
# Synset('trick.n.01') [Synset('entity.n.01')]
# Synset('shtik.n.04') [Synset('entity.n.01')]
# Synset('feint.n.01') [Synset('entity.n.01')]
# Synset('juke.n.02') [Synset('entity.n.01')]
# Synset('footwork.n.02') [Synset('entity.n.01')]
# Synset('ploy.n.02') [Synset('entity.n.01')]
# Synset('ruse.n.01') [Synset('entity.n.01')]
# Synset('means.n.01') [Synset('entity.n.01')]
# Synset('dint.n.01') [Synset('entity.n.01')]
# Synset('escape.n.05') [Synset('entity.n.01')]
# Synset('fast_track.n.01') [Synset('entity.n.01')]
# Synset('instrument.n.02') [Synset('entity.n.01')]
# Synset('road.n.02') [Synset('entity.n.01')]
# Synset('royal_road.n.01') [Synset('entity.n.01')]
# Synset('stepping_stone.n.02') [Synset('entity.n.01')]
# Synset('measure.n.01') [Synset('entity.n.01')]
# Synset('countermeasure.n.01') [Synset('entity.n.01')]
# Synset('bear_hug.n.02') [Synset('entity.n.01')]
# Synset('proxy_fight.n.01') [Synset('entity.n.01')]
# Synset('leveraged_buyout.n.01') [Synset('entity.n.01')]
# Synset('bust-up_takeover.n.01') [Synset('entity.n.01')]
# Synset('shark_repellent.n.01') [Synset('entity.n.01')]
# Synset('golden_parachute.n.01') [Synset('entity.n.01')]
# Synset('greenmail.n.01') [Synset('entity.n.01')]
# Synset('pac-man_strategy.n.01') [Synset('entity.n.01')]
# Synset('poison_pill.n.01') [Synset('entity.n.01')]
# Synset('suicide_pill.n.01') [Synset('entity.n.01')]
# Synset('safe_harbor.n.01') [Synset('entity.n.01')]
# Synset('scorched-earth_policy.n.01') [Synset('entity.n.01')]
# Synset('diagnostic_procedure.n.01') [Synset('entity.n.01')]
# Synset('expedient.n.01') [Synset('entity.n.01')]
# Synset('backstop.n.03') [Synset('entity.n.01')]
# Synset('emergency_procedure.n.01') [Synset('entity.n.01')]
# Synset('experimental_procedure.n.01') [Synset('entity.n.01')]
# Synset('double-blind_procedure.n.01') [Synset('entity.n.01')]
# Synset('makeshift.n.01') [Synset('entity.n.01')]
# Synset('crutch.n.02') [Synset('entity.n.01')]
# Synset('improvisation.n.02') [Synset('entity.n.01')]
# Synset('pis_aller.n.01') [Synset('entity.n.01')]
# Synset('desperate_measure.n.01') [Synset('entity.n.01')]
# Synset('open_sesame.n.01') [Synset('entity.n.01')]
# Synset('salvation.n.02') [Synset('entity.n.01')]
# Synset('tooth.n.04') [Synset('entity.n.01')]
# Synset('voice.n.05') [Synset('entity.n.01')]
# Synset('wings.n.01') [Synset('entity.n.01')]
# Synset('casting_lots.n.01') [Synset('entity.n.01')]
# Synset('resolution.n.11') [Synset('entity.n.01')]
# Synset('adoption.n.01') [Synset('entity.n.01')]
# Synset('embrace.n.03') [Synset('entity.n.01')]
# Synset('election.n.02') [Synset('entity.n.01')]
# Synset('co-option.n.01') [Synset('entity.n.01')]
# Synset('reelection.n.01') [Synset('entity.n.01')]
# Synset('plebiscite.n.01') [Synset('entity.n.01')]
# Synset('referendum.n.01') [Synset('entity.n.01')]
# Synset('election.n.01') [Synset('entity.n.01')]
# Synset('vote.n.02') [Synset('entity.n.01')]
# Synset('general_election.n.01') [Synset('entity.n.01')]
# Synset('primary.n.01') [Synset('entity.n.01')]
# Synset('direct_primary.n.01') [Synset('entity.n.01')]
# Synset('closed_primary.n.01') [Synset('entity.n.01')]
# Synset('open_primary.n.01') [Synset('entity.n.01')]
# Synset('by-election.n.01') [Synset('entity.n.01')]
# Synset('runoff.n.02') [Synset('entity.n.01')]
# Synset('vote.n.01') [Synset('entity.n.01')]
# Synset('block_vote.n.01') [Synset('entity.n.01')]
# Synset('cumulative_vote.n.01') [Synset('entity.n.01')]
# Synset('secret_ballot.n.01') [Synset('entity.n.01')]
# Synset('split_ticket.n.01') [Synset('entity.n.01')]
# Synset('straight_ticket.n.01') [Synset('entity.n.01')]
# Synset('multiple_voting.n.01') [Synset('entity.n.01')]
# Synset('casting_vote.n.01') [Synset('entity.n.01')]
# Synset('reconciliation.n.02') [Synset('entity.n.01')]
# Synset('equation.n.03') [Synset('entity.n.01')]
# Synset('breech_delivery.n.01') [Synset('entity.n.01')]
# Synset('frank_breech.n.01') [Synset('entity.n.01')]
# Synset('cesarean_delivery.n.01') [Synset('entity.n.01')]
# Synset('forceps_delivery.n.01') [Synset('entity.n.01')]
# Synset('midwifery.n.02') [Synset('entity.n.01')]
# Synset('score.n.10') [Synset('entity.n.01')]
# Synset('bowling_score.n.01') [Synset('entity.n.01')]
# Synset('bull's_eye.n.01') [Synset('entity.n.01')]
# Synset('goal.n.04') [Synset('entity.n.01')]
# Synset('own_goal.n.01') [Synset('entity.n.01')]
# Synset('strike.n.04') [Synset('entity.n.01')]
# Synset('spare.n.03') [Synset('entity.n.01')]
# Synset('open_frame.n.01') [Synset('entity.n.01')]
# Synset('audible.n.01') [Synset('entity.n.01')]
# Synset('football_score.n.01') [Synset('entity.n.01')]
# Synset('touchback.n.01') [Synset('entity.n.01')]
# Synset('safety.n.06') [Synset('entity.n.01')]
# Synset('touchdown.n.01') [Synset('entity.n.01')]
# Synset('field_goal.n.01') [Synset('entity.n.01')]
# Synset('conversion.n.03') [Synset('entity.n.01')]
# Synset('point_after.n.01') [Synset('entity.n.01')]
# Synset('baseball_score.n.01') [Synset('entity.n.01')]
# Synset('run.n.01') [Synset('entity.n.01')]
# Synset('earned_run.n.01') [Synset('entity.n.01')]
# Synset('unearned_run.n.01') [Synset('entity.n.01')]
# Synset('run_batted_in.n.01') [Synset('entity.n.01')]
# Synset('basketball_score.n.01') [Synset('entity.n.01')]
# Synset('basket.n.04') [Synset('entity.n.01')]
# Synset('hat_trick.n.01') [Synset('entity.n.01')]
# Synset('solution.n.05') [Synset('entity.n.01')]
# Synset('russian_roulette.n.01') [Synset('entity.n.01')]
# Synset('change.n.03') [Synset('entity.n.01')]
# Synset('filtration.n.02') [Synset('entity.n.01')]
# Synset('percolation.n.03') [Synset('entity.n.01')]
# Synset('reduction.n.03') [Synset('entity.n.01')]
# Synset('schematization.n.02') [Synset('entity.n.01')]
# Synset('economy.n.04') [Synset('entity.n.01')]
# Synset('retrenchment.n.02') [Synset('entity.n.01')]
# Synset('economy_of_scale.n.01') [Synset('entity.n.01')]
# Synset('accommodation.n.06') [Synset('entity.n.01')]
# Synset('adaptation.n.03') [Synset('entity.n.01')]
# Synset('dark_adaptation.n.01') [Synset('entity.n.01')]
# Synset('light_adaptation.n.01') [Synset('entity.n.01')]
# Synset('take-up.n.02') [Synset('entity.n.01')]
# Synset('readjustment.n.01') [Synset('entity.n.01')]
# Synset('domestication.n.03') [Synset('entity.n.01')]
# Synset('decimalization.n.01') [Synset('entity.n.01')]
# Synset('metrification.n.02') [Synset('entity.n.01')]
# Synset('habituation.n.02') [Synset('entity.n.01')]
# Synset('variation.n.02') [Synset('entity.n.01')]
# Synset('variation.n.11') [Synset('entity.n.01')]
# Synset('turning.n.02') [Synset('entity.n.01')]
# Synset('diversification.n.01') [Synset('entity.n.01')]
# Synset('flux.n.08') [Synset('entity.n.01')]
# Synset('switch.n.07') [Synset('entity.n.01')]
# Synset('switcheroo.n.01') [Synset('entity.n.01')]
# Synset('substitution.n.02') [Synset('entity.n.01')]
# Synset('novation.n.01') [Synset('entity.n.01')]
# Synset('pitching_change.n.01') [Synset('entity.n.01')]
# Synset('superannuation.n.03') [Synset('entity.n.01')]
# Synset('supersedure.n.01') [Synset('entity.n.01')]
# Synset('supplanting.n.01') [Synset('entity.n.01')]
# Synset('replacement.n.01') [Synset('entity.n.01')]
# Synset('subrogation.n.01') [Synset('entity.n.01')]
# Synset('weaning.n.01') [Synset('entity.n.01')]
# Synset('promotion.n.02') [Synset('entity.n.01')]
# Synset('preferment.n.01') [Synset('entity.n.01')]
# Synset('demotion.n.01') [Synset('entity.n.01')]
# Synset('investment.n.06') [Synset('entity.n.01')]
# Synset('change_of_state.n.01') [Synset('entity.n.01')]
# Synset('alteration.n.02') [Synset('entity.n.01')]
# Synset('distraction.n.04') [Synset('entity.n.01')]
# Synset('aeration.n.02') [Synset('entity.n.01')]
# Synset('modulation.n.05') [Synset('entity.n.01')]
# Synset('qualification.n.02') [Synset('entity.n.01')]
# Synset('reorganization.n.02') [Synset('entity.n.01')]
# Synset('passage.n.01') [Synset('entity.n.01')]
# Synset('fossilization.n.02') [Synset('entity.n.01')]
# Synset('segue.n.01') [Synset('entity.n.01')]
# Synset('meddling.n.01') [Synset('entity.n.01')]
# Synset('transfer.n.03') [Synset('entity.n.01')]
# Synset('prohibition.n.05') [Synset('entity.n.01')]
# Synset('resistance.n.01') [Synset('entity.n.01')]
# Synset('lockout.n.01') [Synset('entity.n.01')]
# Synset('reaction.n.07') [Synset('entity.n.01')]
# Synset('backlash.n.02') [Synset('entity.n.01')]
# Synset('whitelash.n.01') [Synset('entity.n.01')]
# Synset('rejection.n.01') [Synset('entity.n.01')]
# Synset('brush-off.n.01') [Synset('entity.n.01')]
# Synset('avoidance.n.01') [Synset('entity.n.01')]
# Synset('aversion.n.02') [Synset('entity.n.01')]
# Synset('escape.n.04') [Synset('entity.n.01')]
# Synset('near_thing.n.01') [Synset('entity.n.01')]
# Synset('abandonment.n.01') [Synset('entity.n.01')]
# Synset('exposure.n.10') [Synset('entity.n.01')]
# Synset('apostasy.n.02') [Synset('entity.n.01')]
# Synset('bolt.n.07') [Synset('entity.n.01')]
# Synset('renunciation.n.04') [Synset('entity.n.01')]
# Synset('nonacceptance.n.01') [Synset('entity.n.01')]
# Synset('forsaking.n.01') [Synset('entity.n.01')]
# Synset('abnegation.n.02') [Synset('entity.n.01')]
# Synset('forfeit.n.03') [Synset('entity.n.01')]
# Synset('boycott.n.01') [Synset('entity.n.01')]
# Synset('banishment.n.02') [Synset('entity.n.01')]
# Synset('anathematization.n.01') [Synset('entity.n.01')]
# Synset('disbarment.n.01') [Synset('entity.n.01')]
# Synset('ejection.n.02') [Synset('entity.n.01')]
# Synset('deportation.n.02') [Synset('entity.n.01')]
# Synset('ostracism.n.02') [Synset('entity.n.01')]
# Synset('barring.n.01') [Synset('entity.n.01')]
# Synset('exile.n.03') [Synset('entity.n.01')]
# Synset('babylonian_captivity.n.01') [Synset('entity.n.01')]
# Synset('excommunication.n.02') [Synset('entity.n.01')]
# Synset('relegation.n.03') [Synset('entity.n.01')]
# Synset('rustication.n.05') [Synset('entity.n.01')]
# Synset('ouster.n.03') [Synset('entity.n.01')]
# Synset('deposition.n.04') [Synset('entity.n.01')]
# Synset('suspension.n.07') [Synset('entity.n.01')]
# Synset('rustication.n.04') [Synset('entity.n.01')]
# Synset('displacement.n.07') [Synset('entity.n.01')]
# Synset('veto.n.01') [Synset('entity.n.01')]
# Synset('pocket_veto.n.01') [Synset('entity.n.01')]
# Synset('write-in.n.02') [Synset('entity.n.01')]
# Synset('termination.n.05') [Synset('entity.n.01')]
# Synset('finish.n.09') [Synset('entity.n.01')]
# Synset('finale.n.03') [Synset('entity.n.01')]
# Synset('release.n.12') [Synset('entity.n.01')]
# Synset('completion.n.02') [Synset('entity.n.01')]
# Synset('finalization.n.01') [Synset('entity.n.01')]
# ...
# Synset('lebistes.n.01') [Synset('entity.n.01')]
# Synset('guppy.n.01') [Synset('entity.n.01')]
# Synset('poeciliidae.n.01') [Synset('entity.n.01')]
# Synset('topminnow.n.01') [Synset('entity.n.01')]
# Synset('gambusia.n.01') [Synset('entity.n.01')]
# Synset('mosquitofish.n.01') [Synset('entity.n.01')]
# Synset('platypoecilus.n.01') [Synset('entity.n.01')]
# Synset('platy.n.01') [Synset('entity.n.01')]
# Synset('mollienesia.n.01') [Synset('entity.n.01')]
# Synset('mollie.n.01') [Synset('entity.n.01')]
# Synset('berycomorphi.n.01') [Synset('entity.n.01')]
# Synset('holocentridae.n.01') [Synset('entity.n.01')]
# Synset('holocentrus.n.01') [Synset('entity.n.01')]
# Synset('squirrelfish.n.02') [Synset('entity.n.01')]
# Synset('reef_squirrelfish.n.01') [Synset('entity.n.01')]
# Synset('deepwater_squirrelfish.n.01') [Synset('entity.n.01')]
# Synset('holocentrus_ascensionis.n.01') [Synset('entity.n.01')]
# Synset('soldierfish.n.01') [Synset('entity.n.01')]
# Synset('anomalopidae.n.01') [Synset('entity.n.01')]
# Synset('genus_anomalops.n.01') [Synset('entity.n.01')]
# Synset('anomalops.n.01') [Synset('entity.n.01')]
# Synset('krypterophaneron.n.01') [Synset('entity.n.01')]
# Synset('photoblepharon.n.01') [Synset('entity.n.01')]
# Synset('flashlight_fish.n.01') [Synset('entity.n.01')]
# Synset('zeomorphi.n.01') [Synset('entity.n.01')]
# Synset('zeidae.n.01') [Synset('entity.n.01')]
# Synset('dory.n.03') [Synset('entity.n.01')]
# Synset('zeus.n.02') [Synset('entity.n.01')]
# Synset('john_dory.n.01') [Synset('entity.n.01')]
# Synset('caproidae.n.01') [Synset('entity.n.01')]
# Synset('capros.n.01') [Synset('entity.n.01')]
# Synset('boarfish.n.02') [Synset('entity.n.01')]
# Synset('antigonia.n.01') [Synset('entity.n.01')]
# Synset('boarfish.n.01') [Synset('entity.n.01')]
# Synset('solenichthyes.n.01') [Synset('entity.n.01')]
# Synset('fistulariidae.n.01') [Synset('entity.n.01')]
# Synset('fistularia.n.01') [Synset('entity.n.01')]
# Synset('cornetfish.n.01') [Synset('entity.n.01')]
# Synset('gasterosteidae.n.01') [Synset('entity.n.01')]
# Synset('stickleback.n.01') [Synset('entity.n.01')]
# Synset('gasterosteus.n.01') [Synset('entity.n.01')]
# Synset('three-spined_stickleback.n.01') [Synset('entity.n.01')]
# Synset('ten-spined_stickleback.n.01') [Synset('entity.n.01')]
# Synset('syngnathidae.n.01') [Synset('entity.n.01')]
# Synset('pipefish.n.01') [Synset('entity.n.01')]
# Synset('syngnathus.n.01') [Synset('entity.n.01')]
# Synset('dwarf_pipefish.n.01') [Synset('entity.n.01')]
# Synset('cosmocampus.n.01') [Synset('entity.n.01')]
# Synset('deepwater_pipefish.n.01') [Synset('entity.n.01')]
# Synset('hippocampus.n.02') [Synset('entity.n.01')]
# Synset('seahorse.n.02') [Synset('entity.n.01')]
# Synset('macrorhamphosidae.n.01') [Synset('entity.n.01')]
# Synset('snipefish.n.01') [Synset('entity.n.01')]
# Synset('centriscidae.n.01') [Synset('entity.n.01')]
# Synset('shrimpfish.n.01') [Synset('entity.n.01')]
# Synset('aulostomidae.n.01') [Synset('entity.n.01')]
# Synset('aulostomus.n.01') [Synset('entity.n.01')]
# Synset('trumpetfish.n.01') [Synset('entity.n.01')]
# Synset('cytostome.n.01') [Synset('entity.n.01')]
# Synset('cilium.n.01') [Synset('entity.n.01')]
# Synset('flagellum.n.02') [Synset('entity.n.01')]
# Synset('flame_cell.n.01') [Synset('entity.n.01')]
# Synset('investment.n.04') [Synset('entity.n.01')]
# Synset('pellicle.n.01') [Synset('entity.n.01')]
# Synset('embryo.n.02') [Synset('entity.n.01')]
# Synset('blastocoel.n.01') [Synset('entity.n.01')]
# Synset('blastoderm.n.01') [Synset('entity.n.01')]
# Synset('blastomere.n.01') [Synset('entity.n.01')]
# Synset('fetus.n.01') [Synset('entity.n.01')]
# Synset('monster.n.05') [Synset('entity.n.01')]
# Synset('abortus.n.01') [Synset('entity.n.01')]
# Synset('egg.n.01') [Synset('entity.n.01')]
# Synset('ovipositor.n.01') [Synset('entity.n.01')]
# Synset('chalaza.n.02') [Synset('entity.n.01')]
# Synset('nit.n.02') [Synset('entity.n.01')]
# Synset('spawn.n.01') [Synset('entity.n.01')]
# Synset('roe.n.04') [Synset('entity.n.01')]
# Synset('roe.n.03') [Synset('entity.n.01')]
# Synset('blastula.n.01') [Synset('entity.n.01')]
# Synset('blastocyst.n.01') [Synset('entity.n.01')]
# Synset('trophoblast.n.01') [Synset('entity.n.01')]
# Synset('gastrula.n.01') [Synset('entity.n.01')]
# Synset('morula.n.01') [Synset('entity.n.01')]
# Synset('archenteron.n.01') [Synset('entity.n.01')]
# Synset('blastopore.n.01') [Synset('entity.n.01')]
# Synset('layer.n.05') [Synset('entity.n.01')]
# Synset('embryonic_tissue.n.01') [Synset('entity.n.01')]
# Synset('germ_layer.n.01') [Synset('entity.n.01')]
# Synset('ectoderm.n.01') [Synset('entity.n.01')]
# Synset('neural_tube.n.01') [Synset('entity.n.01')]
# Synset('mesoderm.n.01') [Synset('entity.n.01')]
# Synset('chordamesoderm.n.01') [Synset('entity.n.01')]
# Synset('mesenchyme.n.01') [Synset('entity.n.01')]
# Synset('endoderm.n.01') [Synset('entity.n.01')]
# Synset('silkworm_seed.n.01') [Synset('entity.n.01')]
# Synset('yolk.n.02') [Synset('entity.n.01')]
# Synset('yolk_sac.n.02') [Synset('entity.n.01')]
# Synset('yolk_sac.n.01') [Synset('entity.n.01')]
# Synset('fang.n.04') [Synset('entity.n.01')]
# Synset('fang.n.03') [Synset('entity.n.01')]
# Synset('tusk.n.02') [Synset('entity.n.01')]
# Synset('chordata.n.01') [Synset('entity.n.01')]
# Synset('chordate.n.01') [Synset('entity.n.01')]
# Synset('notochord.n.01') [Synset('entity.n.01')]
# Synset('urochord.n.02') [Synset('entity.n.01')]
# Synset('chordate_family.n.01') [Synset('entity.n.01')]
# Synset('chordate_genus.n.01') [Synset('entity.n.01')]
# Synset('cephalochordata.n.01') [Synset('entity.n.01')]
# Synset('cephalochordate.n.01') [Synset('entity.n.01')]
# Synset('amphioxidae.n.01') [Synset('entity.n.01')]
# Synset('genus_amphioxus.n.01') [Synset('entity.n.01')]
# Synset('lancelet.n.01') [Synset('entity.n.01')]
# Synset('urochordata.n.01') [Synset('entity.n.01')]
# Synset('tunicate.n.01') [Synset('entity.n.01')]
# Synset('ascidiaceae.n.01') [Synset('entity.n.01')]
# Synset('ascidian.n.01') [Synset('entity.n.01')]
# Synset('siphon.n.02') [Synset('entity.n.01')]
# Synset('sea_squirt.n.01') [Synset('entity.n.01')]
# Synset('thaliacea.n.01') [Synset('entity.n.01')]
# Synset('salpidae.n.01') [Synset('entity.n.01')]
# Synset('genus_salpa.n.01') [Synset('entity.n.01')]
# Synset('salp.n.01') [Synset('entity.n.01')]
# Synset('doliolidae.n.01') [Synset('entity.n.01')]
# Synset('genus_doliolum.n.01') [Synset('entity.n.01')]
# Synset('doliolum.n.01') [Synset('entity.n.01')]
# Synset('larvacea.n.01') [Synset('entity.n.01')]
# Synset('larvacean.n.01') [Synset('entity.n.01')]
# Synset('genus_appendicularia.n.01') [Synset('entity.n.01')]
# Synset('appendicularia.n.01') [Synset('entity.n.01')]
# Synset('ascidian_tadpole.n.01') [Synset('entity.n.01')]
# Synset('vertebrata.n.01') [Synset('entity.n.01')]
# Synset('vertebrate.n.01') [Synset('entity.n.01')]
# Synset('amniota.n.01') [Synset('entity.n.01')]
# Synset('amniote.n.01') [Synset('entity.n.01')]
# Synset('amnion.n.01') [Synset('entity.n.01')]
# Synset('chorion.n.01') [Synset('entity.n.01')]
# Synset('chorionic_villus.n.01') [Synset('entity.n.01')]
# Synset('allantois.n.01') [Synset('entity.n.01')]
# Synset('chorioallantois.n.01') [Synset('entity.n.01')]
# Synset('aquatic_vertebrate.n.01') [Synset('entity.n.01')]
# Synset('agnatha.n.01') [Synset('entity.n.01')]
# Synset('jawless_vertebrate.n.01') [Synset('entity.n.01')]
# Synset('ostracodermi.n.01') [Synset('entity.n.01')]
# Synset('ostracoderm.n.01') [Synset('entity.n.01')]
# Synset('heterostraci.n.01') [Synset('entity.n.01')]
# Synset('heterostracan.n.01') [Synset('entity.n.01')]
# Synset('osteostraci.n.01') [Synset('entity.n.01')]
# Synset('osteostracan.n.01') [Synset('entity.n.01')]
# Synset('anaspida.n.01') [Synset('entity.n.01')]
# Synset('anaspid.n.01') [Synset('entity.n.01')]
# Synset('conodonta.n.01') [Synset('entity.n.01')]
# Synset('conodont.n.02') [Synset('entity.n.01')]
# Synset('conodont.n.01') [Synset('entity.n.01')]
# Synset('cyclostomata.n.01') [Synset('entity.n.01')]
# Synset('cyclostome.n.01') [Synset('entity.n.01')]
# Synset('petromyzoniformes.n.01') [Synset('entity.n.01')]
# Synset('petromyzontidae.n.01') [Synset('entity.n.01')]
# Synset('lamprey.n.01') [Synset('entity.n.01')]
# Synset('petromyzon.n.01') [Synset('entity.n.01')]
# Synset('sea_lamprey.n.01') [Synset('entity.n.01')]
# Synset('myxiniformes.n.01') [Synset('entity.n.01')]
# Synset('myxinidae.n.01') [Synset('entity.n.01')]
# Synset('hagfish.n.01') [Synset('entity.n.01')]
# Synset('myxine.n.01') [Synset('entity.n.01')]
# Synset('myxine_glutinosa.n.01') [Synset('entity.n.01')]
# Synset('genus_eptatretus.n.01') [Synset('entity.n.01')]
# Synset('eptatretus.n.01') [Synset('entity.n.01')]
# Synset('myxinikela.n.01') [Synset('entity.n.01')]
# Synset('myxinikela_siroka.n.01') [Synset('entity.n.01')]
# Synset('gnathostomata.n.01') [Synset('entity.n.01')]
# Synset('gnathostome.n.01') [Synset('entity.n.01')]
# Synset('placodermi.n.01') [Synset('entity.n.01')]
# Synset('placoderm.n.01') [Synset('entity.n.01')]
# Synset('chondrichthyes.n.01') [Synset('entity.n.01')]
# Synset('cartilaginous_fish.n.01') [Synset('entity.n.01')]
# Synset('holocephali.n.01') [Synset('entity.n.01')]
# Synset('holocephalan.n.01') [Synset('entity.n.01')]
# Synset('chimaeridae.n.01') [Synset('entity.n.01')]
# Synset('genus_chimaera.n.01') [Synset('entity.n.01')]
# Synset('chimaera.n.03') [Synset('entity.n.01')]
# Synset('rabbitfish.n.01') [Synset('entity.n.01')]
# Synset('elasmobranchii.n.01') [Synset('entity.n.01')]
# Synset('elasmobranch.n.01') [Synset('entity.n.01')]
# Synset('shark.n.01') [Synset('entity.n.01')]
# Synset('hexanchidae.n.01') [Synset('entity.n.01')]
# Synset('hexanchus.n.01') [Synset('entity.n.01')]
# Synset('cow_shark.n.01') [Synset('entity.n.01')]
# Synset('lamnidae.n.01') [Synset('entity.n.01')]
# Synset('isuridae.n.01') [Synset('entity.n.01')]
# Synset('mackerel_shark.n.01') [Synset('entity.n.01')]
# Synset('lamna.n.01') [Synset('entity.n.01')]
# Synset('porbeagle.n.01') [Synset('entity.n.01')]
# Synset('isurus.n.01') [Synset('entity.n.01')]
# Synset('mako.n.01') [Synset('entity.n.01')]
# Synset('shortfin_mako.n.01') [Synset('entity.n.01')]
# Synset('longfin_mako.n.01') [Synset('entity.n.01')]
# Synset('bonito_shark.n.01') [Synset('entity.n.01')]
# Synset('carcharodon.n.01') [Synset('entity.n.01')]
# Synset('great_white_shark.n.01') [Synset('entity.n.01')]
# Synset('cetorhinus.n.01') [Synset('entity.n.01')]
# Synset('cetorhinidae.n.01') [Synset('entity.n.01')]
# Synset('basking_shark.n.01') [Synset('entity.n.01')]
# Synset('alopiidae.n.01') [Synset('entity.n.01')]
# Synset('alopius.n.01') [Synset('entity.n.01')]
# Synset('thresher.n.02') [Synset('entity.n.01')]
# Synset('orectolobidae.n.01') [Synset('entity.n.01')]
# Synset('orectolobus.n.01') [Synset('entity.n.01')]
# Synset('carpet_shark.n.01') [Synset('entity.n.01')]
# Synset('ginglymostoma.n.01') [Synset('entity.n.01')]
# Synset('nurse_shark.n.01') [Synset('entity.n.01')]
# Synset('carchariidae.n.01') [Synset('entity.n.01')]
# Synset('carcharias.n.01') [Synset('entity.n.01')]
# Synset('sand_tiger.n.01') [Synset('entity.n.01')]
# Synset('rhincodontidae.n.01') [Synset('entity.n.01')]
# Synset('rhincodon.n.01') [Synset('entity.n.01')]
# Synset('whale_shark.n.01') [Synset('entity.n.01')]
# Synset('scyliorhinidae.n.01') [Synset('entity.n.01')]
# Synset('cat_shark.n.01') [Synset('entity.n.01')]
# Synset('carcharhinidae.n.01') [Synset('entity.n.01')]
# Synset('requiem_shark.n.01') [Synset('entity.n.01')]
# Synset('carcharhinus.n.01') [Synset('entity.n.01')]
# Synset('bull_shark.n.01') [Synset('entity.n.01')]
# Synset('sandbar_shark.n.02') [Synset('entity.n.01')]
# Synset('blacktip_shark.n.01') [Synset('entity.n.01')]
# Synset('whitetip_shark.n.02') [Synset('entity.n.01')]
# Synset('dusky_shark.n.01') [Synset('entity.n.01')]
# Synset('negaprion.n.01') [Synset('entity.n.01')]
# Synset('lemon_shark.n.01') [Synset('entity.n.01')]
# Synset('prionace.n.01') [Synset('entity.n.01')]
# Synset('blue_shark.n.01') [Synset('entity.n.01')]
# Synset('galeocerdo.n.01') [Synset('entity.n.01')]
# Synset('tiger_shark.n.01') [Synset('entity.n.01')]
# Synset('galeorhinus.n.01') [Synset('entity.n.01')]
# Synset('soupfin_shark.n.01') [Synset('entity.n.01')]
# Synset('dogfish.n.02') [Synset('entity.n.01')]
# Synset('triakidae.n.01') [Synset('entity.n.01')]
# Synset('mustelus.n.01') [Synset('entity.n.01')]
# Synset('smooth_dogfish.n.01') [Synset('entity.n.01')]
# Synset('smoothhound.n.01') [Synset('entity.n.01')]
# Synset('american_smooth_dogfish.n.01') [Synset('entity.n.01')]
# Synset('florida_smoothhound.n.01') [Synset('entity.n.01')]
# Synset('triaenodon.n.01') [Synset('entity.n.01')]
# Synset('whitetip_shark.n.01') [Synset('entity.n.01')]
# Synset('squalidae.n.01') [Synset('entity.n.01')]
# Synset('spiny_dogfish.n.01') [Synset('entity.n.01')]
# Synset('squalus.n.01') [Synset('entity.n.01')]
# Synset('atlantic_spiny_dogfish.n.01') [Synset('entity.n.01')]
# Synset('pacific_spiny_dogfish.n.01') [Synset('entity.n.01')]
# Synset('sphyrnidae.n.01') [Synset('entity.n.01')]
# Synset('sphyrna.n.01') [Synset('entity.n.01')]
# Synset('hammerhead.n.03') [Synset('entity.n.01')]
# Synset('smooth_hammerhead.n.01') [Synset('entity.n.01')]
# Synset('smalleye_hammerhead.n.01') [Synset('entity.n.01')]
# Synset('shovelhead.n.01') [Synset('entity.n.01')]
# Synset('squatinidae.n.01') [Synset('entity.n.01')]
# Synset('squatina.n.01') [Synset('entity.n.01')]
# Synset('angel_shark.n.01') [Synset('entity.n.01')]
# Synset('ray.n.07') [Synset('entity.n.01')]
# Synset('torpediniformes.n.01') [Synset('entity.n.01')]
# Synset('torpedinidae.n.01') [Synset('entity.n.01')]
# Synset('electric_ray.n.01') [Synset('entity.n.01')]
# Synset('rajiformes.n.01') [Synset('entity.n.01')]
# Synset('pristidae.n.01') [Synset('entity.n.01')]
# Synset('sawfish.n.01') [Synset('entity.n.01')]
# Synset('pristis.n.01') [Synset('entity.n.01')]
# Synset('smalltooth_sawfish.n.01') [Synset('entity.n.01')]
# Synset('rhinobatidae.n.01') [Synset('entity.n.01')]
# Synset('guitarfish.n.01') [Synset('entity.n.01')]
# Synset('dasyatidae.n.01') [Synset('entity.n.01')]
# Synset('stingray.n.01') [Synset('entity.n.01')]
# Synset('dasyatis.n.01') [Synset('entity.n.01')]
# Synset('roughtail_stingray.n.01') [Synset('entity.n.01')]
# Synset('gymnura.n.01') [Synset('entity.n.01')]
# Synset('butterfly_ray.n.01') [Synset('entity.n.01')]
# Synset('myliobatidae.n.01') [Synset('entity.n.01')]
# Synset('eagle_ray.n.01') [Synset('entity.n.01')]
# Synset('aetobatus.n.01') [Synset('entity.n.01')]
# Synset('spotted_eagle_ray.n.01') [Synset('entity.n.01')]
# Synset('rhinoptera.n.01') [Synset('entity.n.01')]
# Synset('cownose_ray.n.01') [Synset('entity.n.01')]
# Synset('mobulidae.n.01') [Synset('entity.n.01')]
# Synset('manta.n.02') [Synset('entity.n.01')]
# Synset('genus_manta.n.01') [Synset('entity.n.01')]
# Synset('atlantic_manta.n.01') [Synset('entity.n.01')]
# Synset('mobula.n.01') [Synset('entity.n.01')]
# Synset('devil_ray.n.01') [Synset('entity.n.01')]
# Synset('rajidae.n.01') [Synset('entity.n.01')]
# Synset('skate.n.02') [Synset('entity.n.01')]
# Synset('raja.n.02') [Synset('entity.n.01')]
# Synset('grey_skate.n.01') [Synset('entity.n.01')]
# Synset('little_skate.n.01') [Synset('entity.n.01')]
# Synset('thorny_skate.n.01') [Synset('entity.n.01')]
# Synset('barndoor_skate.n.01') [Synset('entity.n.01')]
# Synset('aves.n.01') [Synset('entity.n.01')]
# Synset('bird.n.01') [Synset('entity.n.01')]
# Synset('dickeybird.n.01') [Synset('entity.n.01')]
# Synset('fledgling.n.02') [Synset('entity.n.01')]
# Synset('nestling.n.01') [Synset('entity.n.01')]
# Synset('bird_family.n.01') [Synset('entity.n.01')]
# Synset('bird_genus.n.01') [Synset('entity.n.01')]
# Synset('breast.n.04') [Synset('entity.n.01')]
# Synset('throat.n.04') [Synset('entity.n.01')]
# Synset('cock.n.05') [Synset('entity.n.01')]
# Synset('gamecock.n.01') [Synset('entity.n.01')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-cb47e75e1a4d> in <module>()
#       1 from nltk.corpus import wordnet as wn
#       2 for s in wn.all_synsets(wn.NOUN):
# ----> 3   if s in wn.all_synsets(wn.NOUN):
#       4     print(s, s.root_hypernyms())
#
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/reader/wordnet.py in __eq__(self, other)
#     196
#     197     def __eq__(self, other):
# --> 198         return self._name == other._name
#     199
#     200     def __ne__(self, other):
#
# KeyboardInterrupt:

# %%
tow = wn.synset('tow.v.01')
shelp = wn.synset('shelp.v.02')
from nltk.corpus import wordnet_ic
brown_ic = wordnet_ic.ic('ic-brown.dat')
tow.jcn_similarity(shelp, brown_ic)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/reader/wordnet.py in synset(self, name)
#    1294         try:
# -> 1295             offset = self._lemma_pos_offset_map[lemma][pos][synset_index]
#    1296         except KeyError:
#
# KeyError: 'v'
#
# During handling of the above exception, another exception occurred:
#
# WordNetError                              Traceback (most recent call last)
# <ipython-input-60-fa53c74dd8e9> in <module>()
#       1 tow = wn.synset('tow.v.01')
# ----> 2 shelp = wn.synset('shelp.v.02')
#       3 from nltk.corpus import wordnet_ic
#       4 brown_ic = wordnet_ic.ic('ic-brown.dat')
#       5 tow.jcn_similarity(shelp, brown_ic)
#
# /usr/local/lib/python3.6/dist-packages/nltk/corpus/reader/wordnet.py in synset(self, name)
#    1296         except KeyError:
#    1297             message = 'no lemma %r with part of speech %r'
# -> 1298             raise WordNetError(message % (lemma, pos))
#    1299         except IndexError:
#    1300             n_senses = len(self._lemma_pos_offset_map[lemma][pos])
#
# WordNetError: no lemma 'shelp' with part of speech 'v'

# %%
s = wn.synset("lincoln.n.01")
s.max_depth() > 0

# %%
genesis_ic = wn.ic(genesis, True, 1.0)

# %%
for ii in wn.all_synsets(): pass
for ii in wn.all_synsets(): pass

# %%
google = wordnet.synsets("google")[0]
earth = wordnet.synsets("earth")[0]
google.wup_similarity(earth)

# %%
t = wn.synsets('fly', wn.VERB)[0]
s = wn.synsets('say', wn.VERB)[0]
print(s.shortest_path_distance(t))

# %%
print(s.path_similarity(t, simulate_root=False))

# %%
print(s.lch_similarity(t, simulate_root=False))

# %%
print(s.wup_similarity(t, simulate_root=False))
# Out:
# 0.09523809523809523

# %%
from nltk.corpus import wordnet
wordnet.synsets("pants", 'n')
# Out:
# [Synset('bloomers.n.01'),
#  Synset('pant.n.01'),
#  Synset('trouser.n.01'),
#  Synset('gasp.n.01')]

# %%
from nltk.stem.wordnet import WordNetLemmatizer
WordNetLemmatizer().lemmatize("eggs", pos="n")
# Out:
# 'egg'

# %%
WordNetLemmatizer().lemmatize("legs", pos="n")
# Out:
# 'leg'

# %%
wn.synset('join.n.02').lch_similarity(wn.synset('dog.n.01'))
# Out:
# 0.9985288301111273

# %%
wn.synset('john.n.02').wup_similarity(wn.synset('dog.n.01'))
# Out:
# 0.5714285714285714

# %%
wn.synset('john.n.02').res_similarity(wn.synset('dog.n.01'), brown_ic)
# Out:
# 2.2241504712318556

# %%
wn.synset('john.n.02').jcn_similarity(wn.synset('dog.n.01'), brown_ic)
# Out:
# 0.07573904012412865

# %%
wn.synset('john.n.02').lin_similarity(wn.synset('dog.n.01'), brown_ic)
# Out:
# 0.25200651695826864

# %%
wn.synset('john.n.02').hypernym_paths()
# Out:
# [[Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('causal_agent.n.01'),
#   Synset('person.n.01'),
#   Synset('communicator.n.01'),
#   Synset('negotiator.n.01'),
#   Synset('representative.n.01'),
#   Synset('head_of_state.n.01'),
#   Synset('sovereign.n.01'),
#   Synset('king.n.01'),
#   Synset('king_of_england.n.01'),
#   Synset('john.n.02')],
#  [Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('object.n.01'),
#   Synset('whole.n.02'),
#   Synset('living_thing.n.01'),
#   Synset('organism.n.01'),
#   Synset('person.n.01'),
#   Synset('communicator.n.01'),
#   Synset('negotiator.n.01'),
#   Synset('representative.n.01'),
#   Synset('head_of_state.n.01'),
#   Synset('sovereign.n.01'),
#   Synset('king.n.01'),
#   Synset('king_of_england.n.01'),
#   Synset('john.n.02')],
#  [Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('causal_agent.n.01'),
#   Synset('person.n.01'),
#   Synset('ruler.n.01'),
#   Synset('sovereign.n.01'),
#   Synset('king.n.01'),
#   Synset('king_of_england.n.01'),
#   Synset('john.n.02')],
#  [Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('object.n.01'),
#   Synset('whole.n.02'),
#   Synset('living_thing.n.01'),
#   Synset('organism.n.01'),
#   Synset('person.n.01'),
#   Synset('ruler.n.01'),
#   Synset('sovereign.n.01'),
#   Synset('king.n.01'),
#   Synset('king_of_england.n.01'),
#   Synset('john.n.02')]]

# %%
wn.synset('code.n.03').topic_domains()
# Out:
# [Synset('computer_science.n.01')]

# %%
wn.synset('pukka.a.01').region_domains()
# Out:
# [Synset('india.n.01')]

# %%
wn.synset('freaky.a.01').usage_domains()
# Out:
# [Synset('slang.n.02')]

# %%
wn.synsets("brunch")
# Out:
# [Synset('brunch.n.01'), Synset('brunch.v.01')]

# %%
wn.synset('policeman.n.01').lowest_common_hypernyms(wn.synset('chef.n.01'))
# Out:
# [Synset('person.n.01')]
